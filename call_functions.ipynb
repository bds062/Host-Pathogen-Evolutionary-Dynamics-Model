# %%
from model_functions import Model, RasterModel, GraphModel
import numpy as np
import time

# %%
param1_values = np.linspace(200, 365, 15)
param2_values = np.linspace(100, 200, 15)



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 182.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 8 processes...
# Total iterations: 225
# Progress: 0% complete
# Completed simulation for infected_time=200.0, infected_time2=121.42857142857143 with result=1.0
# Completed simulation for infected_time=200.0, infected_time2=100.0 with result=1.0
# Completed simulation for infected_time=200.0, infected_time2=150.0 with result=1.0
# Completed simulation for infected_time=200.0, infected_time2=128.57142857142858 with result=1.0
# Completed simulation for infected_time=200.0, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=200.0, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=200.0, infected_time2=142.85714285714286 with result=1.0
# Completed simulation for infected_time=200.0, infected_time2=135.71428571428572 with result=1.0
# Completed simulation for infected_time=200.0, infected_time2=157.14285714285714 with result=1.0
# Completed simulation for infected_time=200.0, infected_time2=164.28571428571428 with result=0.9999999999999989
# Completed simulation for infected_time=200.0, infected_time2=171.42857142857144 with result=0.9999999999923318
# Completed simulation for infected_time=200.0, infected_time2=178.57142857142856 with result=0.9999999840618222
# Completed simulation for infected_time=200.0, infected_time2=185.71428571428572 with result=0.9999875867307918
# Completed simulation for infected_time=200.0, infected_time2=192.85714285714286 with result=0.9954846602099983
# Completed simulation for infected_time=200.0, infected_time2=200.0 with result=0.5
# Completed simulation for infected_time=211.78571428571428, infected_time2=100.0 with result=1.0
# Completed simulation for infected_time=211.78571428571428, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=211.78571428571428, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=211.78571428571428, infected_time2=121.42857142857143 with result=1.0
# Completed simulation for infected_time=211.78571428571428, infected_time2=135.71428571428572 with result=1.0
# Completed simulation for infected_time=211.78571428571428, infected_time2=128.57142857142858 with result=1.0
# Completed simulation for infected_time=211.78571428571428, infected_time2=142.85714285714286 with result=1.0
# Completed simulation for infected_time=211.78571428571428, infected_time2=150.0 with result=1.0
# Completed simulation for infected_time=211.78571428571428, infected_time2=157.14285714285714 with result=1.0
# Completed simulation for infected_time=211.78571428571428, infected_time2=164.28571428571428 with result=1.0
# Completed simulation for infected_time=211.78571428571428, infected_time2=171.42857142857144 with result=0.9999999999999836
# Completed simulation for infected_time=211.78571428571428, infected_time2=178.57142857142856 with result=0.9999999999723388
# Completed simulation for infected_time=211.78571428571428, infected_time2=185.71428571428572 with result=0.9999999821458913
# Completed simulation for infected_time=211.78571428571428, infected_time2=192.85714285714286 with result=0.9999948043888246
# Completed simulation for infected_time=211.78571428571428, infected_time2=200.0 with result=0.9991987607350922
# Completed simulation for infected_time=223.57142857142858, infected_time2=100.0 with result=1.0
# Completed simulation for infected_time=223.57142857142858, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=223.57142857142858, infected_time2=121.42857142857143 with result=1.0
# Completed simulation for infected_time=223.57142857142858, infected_time2=128.57142857142858 with result=1.0
# Completed simulation for infected_time=223.57142857142858, infected_time2=135.71428571428572 with result=1.0
# Completed simulation for infected_time=223.57142857142858, infected_time2=142.85714285714286 with result=1.0
# Completed simulation for infected_time=223.57142857142858, infected_time2=150.0 with result=1.0
# Completed simulation for infected_time=223.57142857142858, infected_time2=157.14285714285714 with result=1.0
# Completed simulation for infected_time=223.57142857142858, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=223.57142857142858, infected_time2=164.28571428571428 with result=1.0
# Completed simulation for infected_time=223.57142857142858, infected_time2=171.42857142857144 with result=0.9999999999999296
# Completed simulation for infected_time=223.57142857142858, infected_time2=178.57142857142856 with result=0.999999999864344
# Completed simulation for infected_time=223.57142857142858, infected_time2=185.71428571428572 with result=0.9999999012643632
# Completed simulation for infected_time=223.57142857142858, infected_time2=192.85714285714286 with result=0.9999676262785021
# Completed simulation for infected_time=223.57142857142858, infected_time2=200.0 with result=0.9943319729693815
# Completed simulation for infected_time=235.35714285714286, infected_time2=100.0 with result=1.0
# Completed simulation for infected_time=235.35714285714286, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=235.35714285714286, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=235.35714285714286, infected_time2=121.42857142857143 with result=1.0
# Completed simulation for infected_time=235.35714285714286, infected_time2=128.57142857142858 with result=1.0
# Completed simulation for infected_time=235.35714285714286, infected_time2=135.71428571428572 with result=1.0
# Completed simulation for infected_time=235.35714285714286, infected_time2=142.85714285714286 with result=1.0
# Completed simulation for infected_time=235.35714285714286, infected_time2=150.0 with result=1.0
# Completed simulation for infected_time=235.35714285714286, infected_time2=157.14285714285714 with result=1.0
# Completed simulation for infected_time=235.35714285714286, infected_time2=164.28571428571428 with result=0.9999999999937782
# Completed simulation for infected_time=235.35714285714286, infected_time2=171.42857142857144 with result=0.9999999054966064
# Completed simulation for infected_time=235.35714285714286, infected_time2=178.57142857142856 with result=0.9996014348140381
# Completed simulation for infected_time=235.35714285714286, infected_time2=185.71428571428572 with result=0.6804030981862266
# Completed simulation for infected_time=235.35714285714286, infected_time2=192.85714285714286 with result=0.005135586082622784
# Completed simulation for infected_time=235.35714285714286, infected_time2=200.0 with result=2.318375986183505e-05
# Completed simulation for infected_time=247.14285714285714, infected_time2=100.0 with result=1.0
# Completed simulation for infected_time=247.14285714285714, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=247.14285714285714, infected_time2=121.42857142857143 with result=1.0
# Completed simulation for infected_time=247.14285714285714, infected_time2=135.71428571428572 with result=1.0
# Completed simulation for infected_time=247.14285714285714, infected_time2=128.57142857142858 with result=1.0
# Completed simulation for infected_time=247.14285714285714, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=247.14285714285714, infected_time2=142.85714285714286 with result=1.0
# Completed simulation for infected_time=247.14285714285714, infected_time2=150.0 with result=0.9999999999999998
# Completed simulation for infected_time=247.14285714285714, infected_time2=157.14285714285714 with result=0.999999999620349
# Completed simulation for infected_time=247.14285714285714, infected_time2=164.28571428571428 with result=0.9998751933926294
# Completed simulation for infected_time=247.14285714285714, infected_time2=171.42857142857144 with result=0.39457027512300474
# Completed simulation for infected_time=247.14285714285714, infected_time2=178.57142857142856 with result=0.00017508214346538653
# Completed simulation for infected_time=247.14285714285714, infected_time2=185.71428571428572 with result=9.76802686472099e-08
# Completed simulation for infected_time=247.14285714285714, infected_time2=200.0 with result=1.4284687420888046e-12
# Completed simulation for infected_time=258.92857142857144, infected_time2=100.0 with result=1.0
# Completed simulation for infected_time=258.92857142857144, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=258.92857142857144, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=247.14285714285714, infected_time2=192.85714285714286 with result=2.1727966418852065e-10
# Completed simulation for infected_time=258.92857142857144, infected_time2=121.42857142857143 with result=1.0
# Completed simulation for infected_time=258.92857142857144, infected_time2=128.57142857142858 with result=1.0
# Completed simulation for infected_time=258.92857142857144, infected_time2=135.71428571428572 with result=1.0
# Completed simulation for infected_time=258.92857142857144, infected_time2=142.85714285714286 with result=1.0
# Completed simulation for infected_time=258.92857142857144, infected_time2=150.0 with result=0.999999999691313
# Completed simulation for infected_time=258.92857142857144, infected_time2=157.14285714285714 with result=0.9958525200984792
# Completed simulation for infected_time=258.92857142857144, infected_time2=164.28571428571428 with result=0.008610353258561132
# Completed simulation for infected_time=258.92857142857144, infected_time2=171.42857142857144 with result=1.464705835788918e-07
# Completed simulation for infected_time=258.92857142857144, infected_time2=178.57142857142856 with result=2.1428339389670122e-11
# Completed simulation for infected_time=258.92857142857144, infected_time2=185.71428571428572 with result=1.7998521508386778e-14
# Completed simulation for infected_time=258.92857142857144, infected_time2=192.85714285714286 with result=5.70633648384557e-17
# Completed simulation for infected_time=258.92857142857144, infected_time2=200.0 with result=5.072131375573484e-19
# Completed simulation for infected_time=270.7142857142857, infected_time2=100.0 with result=1.0
# Completed simulation for infected_time=270.7142857142857, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=270.7142857142857, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=270.7142857142857, infected_time2=121.42857142857143 with result=1.0
# Completed simulation for infected_time=270.7142857142857, infected_time2=128.57142857142858 with result=1.0
# Completed simulation for infected_time=270.7142857142857, infected_time2=135.71428571428572 with result=1.0
# Completed simulation for infected_time=270.7142857142857, infected_time2=142.85714285714286 with result=0.9999999999974623
# Completed simulation for infected_time=270.7142857142857, infected_time2=150.0 with result=0.9985802052050767
# Completed simulation for infected_time=270.7142857142857, infected_time2=157.14285714285714 with result=0.003312627918700723
# Completed simulation for infected_time=270.7142857142857, infected_time2=164.28571428571428 with result=7.492688863821441e-09
# Completed simulation for infected_time=270.7142857142857, infected_time2=171.42857142857144 with result=2.2315997652517607e-13
# Completed simulation for infected_time=270.7142857142857, infected_time2=185.71428571428572 with result=5.570418545790366e-20
# Completed simulation for infected_time=270.7142857142857, infected_time2=192.85714285714286 with result=2.2696239122797533e-22
# Completed simulation for infected_time=270.7142857142857, infected_time2=200.0 with result=2.4906548373466796e-24
# Completed simulation for infected_time=282.5, infected_time2=100.0 with result=1.0
# Completed simulation for infected_time=282.5, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=282.5, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=270.7142857142857, infected_time2=178.57142857142856 with result=4.910661813873234e-17
# Completed simulation for infected_time=282.5, infected_time2=121.42857142857143 with result=1.0
# Completed simulation for infected_time=282.5, infected_time2=128.57142857142858 with result=1.0
# Completed simulation for infected_time=282.5, infected_time2=135.71428571428572 with result=0.9999999999999998
# Completed simulation for infected_time=282.5, infected_time2=142.85714285714286 with result=0.9999958411770591
# Completed simulation for infected_time=282.5, infected_time2=150.0 with result=0.02474750756767207
# Completed simulation for infected_time=282.5, infected_time2=157.14285714285714 with result=6.0161410618939616e-09
# Completed simulation for infected_time=282.5, infected_time2=164.28571428571428 with result=3.888657039614879e-14
# Completed simulation for infected_time=282.5, infected_time2=178.57142857142856 with result=1.2711694951948235e-21
# Completed simulation for infected_time=282.5, infected_time2=171.42857142857144 with result=2.945485021322755e-18
# Completed simulation for infected_time=282.5, infected_time2=185.71428571428572 with result=2.0091415137031037e-24
# Completed simulation for infected_time=282.5, infected_time2=192.85714285714286 with result=9.770423467428618e-27
# Completed simulation for infected_time=282.5, infected_time2=200.0 with result=1.2357272835133108e-28
# Completed simulation for infected_time=294.2857142857143, infected_time2=100.0 with result=1.0
# Completed simulation for infected_time=294.2857142857143, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=294.2857142857143, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=294.2857142857143, infected_time2=121.42857142857143 with result=1.0
# Completed simulation for infected_time=294.2857142857143, infected_time2=128.57142857142858 with result=1.0
# Completed simulation for infected_time=294.2857142857143, infected_time2=135.71428571428572 with result=0.9999999999621062
# Completed simulation for infected_time=294.2857142857143, infected_time2=142.85714285714286 with result=0.5960272538935255
# Completed simulation for infected_time=294.2857142857143, infected_time2=150.0 with result=9.921563226440797e-08
# Completed simulation for infected_time=294.2857142857143, infected_time2=157.14285714285714 with result=6.25910213622329e-14
# Completed simulation for infected_time=294.2857142857143, infected_time2=164.28571428571428 with result=1.0913868642694324e-18
# Completed simulation for infected_time=294.2857142857143, infected_time2=171.42857142857144 with result=1.8616487111228345e-22
# Completed simulation for infected_time=294.2857142857143, infected_time2=178.57142857142856 with result=1.5774384968490302e-25
# Completed simulation for infected_time=294.2857142857143, infected_time2=192.85714285714286 with result=2.9720558470070956e-30
# Completed simulation for infected_time=294.2857142857143, infected_time2=200.0 with result=4.2709275969790055e-32
# Completed simulation for infected_time=306.07142857142856, infected_time2=100.0 with result=1.0
# Completed simulation for infected_time=294.2857142857143, infected_time2=185.71428571428572 with result=4.346670889036894e-28
# Completed simulation for infected_time=306.07142857142856, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=306.07142857142856, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=306.07142857142856, infected_time2=121.42857142857143 with result=1.0
# Completed simulation for infected_time=306.07142857142856, infected_time2=128.57142857142858 with result=1.0
# Completed simulation for infected_time=306.07142857142856, infected_time2=135.71428571428572 with result=0.9999894104291589
# Completed simulation for infected_time=306.07142857142856, infected_time2=142.85714285714286 with result=7.672256005083888e-05
# Completed simulation for infected_time=306.07142857142856, infected_time2=150.0 with result=1.7841240023454288e-12
# Completed simulation for infected_time=306.07142857142856, infected_time2=164.28571428571428 with result=1.3389359801970982e-22
# Completed simulation for infected_time=306.07142857142856, infected_time2=171.42857142857144 with result=4.559233126861996e-26
# Completed simulation for infected_time=306.07142857142856, infected_time2=178.57142857142856 with result=6.858808371057319e-29
# Completed simulation for infected_time=306.07142857142856, infected_time2=157.14285714285714 with result=3.273787548648521e-18
# Completed simulation for infected_time=306.07142857142856, infected_time2=185.71428571428572 with result=3.0734663027467173e-31
# Completed simulation for infected_time=306.07142857142856, infected_time2=192.85714285714286 with result=3.190052185431955e-33
# Completed simulation for infected_time=306.07142857142856, infected_time2=200.0 with result=6.370798512786876e-35
# Completed simulation for infected_time=317.8571428571429, infected_time2=100.0 with result=1.0
# Completed simulation for infected_time=317.8571428571429, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=317.8571428571429, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=317.8571428571429, infected_time2=121.42857142857143 with result=1.0
# Completed simulation for infected_time=317.8571428571429, infected_time2=135.71428571428572 with result=0.6793356523168956
# Completed simulation for infected_time=317.8571428571429, infected_time2=128.57142857142858 with result=0.9999999999999841
# Completed simulation for infected_time=317.8571428571429, infected_time2=142.85714285714286 with result=2.1057255096144937e-09
# Completed simulation for infected_time=317.8571428571429, infected_time2=150.0 with result=1.5336917516999353e-16
# Completed simulation for infected_time=317.8571428571429, infected_time2=157.14285714285714 with result=6.979101303707221e-22
# Completed simulation for infected_time=317.8571428571429, infected_time2=164.28571428571428 with result=5.865830259493258e-26
# Completed simulation for infected_time=317.8571428571429, infected_time2=171.42857142857144 with result=3.583074864730614e-29
# Completed simulation for infected_time=317.8571428571429, infected_time2=178.57142857142856 with result=8.76465098324263e-32
# Completed simulation for infected_time=317.8571428571429, infected_time2=185.71428571428572 with result=5.932631333914429e-34
# Completed simulation for infected_time=317.8571428571429, infected_time2=200.0 with result=2.390111209389088e-37
# Completed simulation for infected_time=317.8571428571429, infected_time2=192.85714285714286 with result=8.781999250493324e-36
# Completed simulation for infected_time=329.6428571428571, infected_time2=100.0 with result=1.0
# Completed simulation for infected_time=329.6428571428571, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=329.6428571428571, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=329.6428571428571, infected_time2=121.42857142857143 with result=1.0
# Completed simulation for infected_time=329.6428571428571, infected_time2=128.57142857142858 with result=0.9999999997194814
# Completed simulation for infected_time=329.6428571428571, infected_time2=135.71428571428572 with result=0.00044118516028129363
# Completed simulation for infected_time=329.6428571428571, infected_time2=142.85714285714286 with result=2.6633942374859016e-13
# Completed simulation for infected_time=329.6428571428571, infected_time2=157.14285714285714 with result=4.941875703527805e-25
# Completed simulation for infected_time=329.6428571428571, infected_time2=164.28571428571428 with result=7.609956680996678e-29
# Completed simulation for infected_time=329.6428571428571, infected_time2=171.42857142857144 with result=7.606971893489655e-32
# Completed simulation for infected_time=329.6428571428571, infected_time2=150.0 with result=5.067393897755491e-20
# Completed simulation for infected_time=329.6428571428571, infected_time2=178.57142857142856 with result=2.8057159141625634e-34
# Completed simulation for infected_time=329.6428571428571, infected_time2=185.71428571428572 with result=2.692600782041221e-36
# Completed simulation for infected_time=329.6428571428571, infected_time2=192.85714285714286 with result=5.385043070749937e-38
# Completed simulation for infected_time=329.6428571428571, infected_time2=200.0 with result=1.9057648489067925e-39
# Completed simulation for infected_time=341.42857142857144, infected_time2=100.0 with result=1.0
# Completed simulation for infected_time=341.42857142857144, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=341.42857142857144, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=341.42857142857144, infected_time2=128.57142857142858 with result=0.999997206353121
# Completed simulation for infected_time=341.42857142857144, infected_time2=135.71428571428572 with result=7.443774027708421e-08
# Completed simulation for infected_time=341.42857142857144, infected_time2=142.85714285714286 with result=1.2513835092832688e-16
# Completed simulation for infected_time=341.42857142857144, infected_time2=121.42857142857143 with result=1.0
# Completed simulation for infected_time=341.42857142857144, infected_time2=150.0 with result=5.309394483430747e-23
# Completed simulation for infected_time=341.42857142857144, infected_time2=157.14285714285714 with result=9.804806665422334e-28
# Completed simulation for infected_time=341.42857142857144, infected_time2=164.28571428571428 with result=2.511649902714922e-31
# Completed simulation for infected_time=341.42857142857144, infected_time2=171.42857142857144 with result=3.8029707848325974e-34
# Completed simulation for infected_time=341.42857142857144, infected_time2=178.57142857142856 with result=1.9846403756134382e-36
# Completed simulation for infected_time=341.42857142857144, infected_time2=185.71428571428572 with result=2.559684491716606e-38
# Completed simulation for infected_time=341.42857142857144, infected_time2=192.85714285714286 with result=6.606884196557248e-40
# Completed simulation for infected_time=341.42857142857144, infected_time2=200.0 with result=2.922009356728592e-41
# Completed simulation for infected_time=353.2142857142857, infected_time2=100.0 with result=1.0
# Completed simulation for infected_time=353.2142857142857, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=353.2142857142857, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=353.2142857142857, infected_time2=121.42857142857143 with result=0.9999999999999999
# Completed simulation for infected_time=353.2142857142857, infected_time2=128.57142857142858 with result=0.9865058324289147
# Completed simulation for infected_time=353.2142857142857, infected_time2=135.71428571428572 with result=4.5855396804232905e-11
# Completed simulation for infected_time=353.2142857142857, infected_time2=142.85714285714286 with result=1.7724354939248557e-19
# Completed simulation for infected_time=353.2142857142857, infected_time2=157.14285714285714 with result=4.640710430982465e-30
# Completed simulation for infected_time=353.2142857142857, infected_time2=164.28571428571428 with result=1.8251375749277687e-33
# Completed simulation for infected_time=353.2142857142857, infected_time2=171.42857142857144 with result=3.924589509830126e-36
# Completed simulation for infected_time=353.2142857142857, infected_time2=150.0 with result=1.4703862521993864e-25
# Completed simulation for infected_time=353.2142857142857, infected_time2=178.57142857142856 with result=2.7476432909280933e-38
# Completed simulation for infected_time=353.2142857142857, infected_time2=185.71428571428572 with result=4.55344183234833e-40
# Completed simulation for infected_time=353.2142857142857, infected_time2=192.85714285714286 with result=1.459581705905881e-41
# Completed simulation for infected_time=353.2142857142857, infected_time2=200.0 with result=7.80170678889602e-43
# Completed simulation for infected_time=365.0, infected_time2=100.0 with result=0.9999999999999999
# Completed simulation for infected_time=365.0, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=114.28571428571429 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=128.57142857142858 with result=0.0724035692455996
# Completed simulation for infected_time=365.0, infected_time2=135.71428571428572 with result=8.154814914767663e-14
# Completed simulation for infected_time=365.0, infected_time2=142.85714285714286 with result=6.305903327358765e-22
# Completed simulation for infected_time=365.0, infected_time2=121.42857142857143 with result=0.9999999999998803
# Completed simulation for infected_time=365.0, infected_time2=150.0 with result=9.191796812119515e-28
# Completed simulation for infected_time=365.0, infected_time2=157.14285714285714 with result=4.5592917397595007e-32
# Completed simulation for infected_time=365.0, infected_time2=164.28571428571428 with result=2.577077597985228e-35
# Completed simulation for infected_time=365.0, infected_time2=171.42857142857144 with result=7.461058107612604e-38
# Completed simulation for infected_time=365.0, infected_time2=178.57142857142856 with result=6.7046043237806774e-40
# Completed simulation for infected_time=365.0, infected_time2=185.71428571428572 with result=1.3752433336304121e-41
# Completed simulation for infected_time=365.0, infected_time2=192.85714285714286 with result=5.301342410365813e-43
# Completed simulation for infected_time=365.0, infected_time2=200.0 with result=3.3301633819158574e-44
#
# Raster process complete in 8220.5s!
# Max value: 1.0
# At infected_time = 200.0 and infected_time2 = 100.0
#
# Total execution time: 8220.59 seconds

# %%
param1_values = np.linspace(0, 365, 20)
param2_values = np.linspace(0, 365, 20)



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 302.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 8 processes...
# Total iterations: 400
# Progress: 0% complete
# Completed simulation for infected_time=0.0, infected_time2=0.0 with result=0.5
# Completed simulation for infected_time=57.63157894736842, infected_time2=19.210526315789473 with result=9.675524210166374e-22
# Completed simulation for infected_time=38.421052631578945, infected_time2=19.210526315789473 with result=4.1091395177672784e-13
# Completed simulation for infected_time=19.210526315789473, infected_time2=19.210526315789473 with result=0.5
# Completed simulation for infected_time=38.421052631578945, infected_time2=0.0 with result=8.185980865965794e-24
# Completed simulation for infected_time=57.63157894736842, infected_time2=0.0 with result=1.4951855860060476e-30
# Completed simulation for infected_time=19.210526315789473, infected_time2=0.0 with result=2.915896757636562e-14
# Completed simulation for infected_time=38.421052631578945, infected_time2=38.421052631578945 with result=0.5
# Completed simulation for infected_time=57.63157894736842, infected_time2=38.421052631578945 with result=1.2734658689043985e-11
# Completed simulation for infected_time=57.63157894736842, infected_time2=57.63157894736842 with result=0.5
# Completed simulation for infected_time=76.84210526315789, infected_time2=0.0 with result=2.968008070494382e-35
# Completed simulation for infected_time=76.84210526315789, infected_time2=19.210526315789473 with result=8.536162504008214e-28
# Completed simulation for infected_time=76.84210526315789, infected_time2=38.421052631578945 with result=3.5989640596562675e-19
# Completed simulation for infected_time=76.84210526315789, infected_time2=76.84210526315789 with result=0.5
# Completed simulation for infected_time=76.84210526315789, infected_time2=57.63157894736842 with result=5.786317055328839e-10
# Completed simulation for infected_time=96.05263157894737, infected_time2=0.0 with result=1.6310529187782457e-38
# Completed simulation for infected_time=96.05263157894737, infected_time2=38.421052631578945 with result=1.7410885335442738e-24
# Completed simulation for infected_time=96.05263157894737, infected_time2=19.210526315789473 with result=5.09821168583393e-32
# Completed simulation for infected_time=96.05263157894737, infected_time2=57.63157894736842 with result=2.232091845776217e-16
# Completed simulation for infected_time=96.05263157894737, infected_time2=96.05263157894737 with result=0.5
# Completed simulation for infected_time=96.05263157894737, infected_time2=76.84210526315789 with result=2.476461582891258e-08
# Completed simulation for infected_time=115.26315789473684, infected_time2=0.0 with result=6.74149499009019e-41
# Completed simulation for infected_time=115.26315789473684, infected_time2=38.421052631578945 with result=3.0722645261049776e-28
# Completed simulation for infected_time=115.26315789473684, infected_time2=19.210526315789473 with result=5.735815860775342e-35
# Completed simulation for infected_time=115.26315789473684, infected_time2=76.84210526315789 with result=1.1146587165430151e-13
# Completed simulation for infected_time=115.26315789473684, infected_time2=57.63157894736842 with result=5.7953965574368325e-21
# Completed simulation for infected_time=115.26315789473684, infected_time2=96.05263157894737 with result=6.720050400795657e-07
# Completed simulation for infected_time=134.4736842105263, infected_time2=0.0 with result=8.366812090154047e-43
# Completed simulation for infected_time=115.26315789473684, infected_time2=115.26315789473684 with result=0.5
# Completed simulation for infected_time=134.4736842105263, infected_time2=19.210526315789473 with result=3.7456799557461306e-37
# Completed simulation for infected_time=134.4736842105263, infected_time2=38.421052631578945 with result=6.494063488999097e-31
# Completed simulation for infected_time=134.4736842105263, infected_time2=57.63157894736842 with result=2.774497782428391e-24
# Completed simulation for infected_time=134.4736842105263, infected_time2=76.84210526315789 with result=1.3210972780550556e-17
# Completed simulation for infected_time=134.4736842105263, infected_time2=96.05263157894737 with result=2.44543536939091e-11
# Completed simulation for infected_time=134.4736842105263, infected_time2=115.26315789473684 with result=9.450079424983528e-06
# Completed simulation for infected_time=134.4736842105263, infected_time2=134.4736842105263 with result=0.5
# Completed simulation for infected_time=153.68421052631578, infected_time2=0.0 with result=2.298854783496786e-44
# Completed simulation for infected_time=153.68421052631578, infected_time2=19.210526315789473 with result=6.26566977103639e-39
# Completed simulation for infected_time=153.68421052631578, infected_time2=38.421052631578945 with result=6.068767209890375e-33
# Completed simulation for infected_time=153.68421052631578, infected_time2=57.63157894736842 with result=1.005904480799706e-26
# Completed simulation for infected_time=153.68421052631578, infected_time2=76.84210526315789 with result=1.5193417265366408e-20
# Completed simulation for infected_time=153.68421052631578, infected_time2=96.05263157894737 with result=1.0453950319912395e-14
# Completed simulation for infected_time=153.68421052631578, infected_time2=115.26315789473684 with result=1.798595038584032e-09
# Completed simulation for infected_time=153.68421052631578, infected_time2=134.4736842105263 with result=7.061442992810187e-05
# Completed simulation for infected_time=153.68421052631578, infected_time2=153.68421052631578 with result=0.5
# Completed simulation for infected_time=172.89473684210526, infected_time2=0.0 with result=1.1465141623241832e-45
# Completed simulation for infected_time=172.89473684210526, infected_time2=19.210526315789473 with result=2.0482923927664723e-40
# Completed simulation for infected_time=172.89473684210526, infected_time2=38.421052631578945 with result=1.2511390682158748e-34
# Completed simulation for infected_time=172.89473684210526, infected_time2=57.63157894736842 with result=1.2333104838586873e-28
# Completed simulation for infected_time=172.89473684210526, infected_time2=76.84210526315789 with result=8.6318551189759e-23
# Completed simulation for infected_time=172.89473684210526, infected_time2=96.05263157894737 with result=2.4967377219580017e-17
# Completed simulation for infected_time=172.89473684210526, infected_time2=134.4736842105263 with result=4.654866989269434e-08
# Completed simulation for infected_time=172.89473684210526, infected_time2=115.26315789473684 with result=2.1246052482998367e-12
# Completed simulation for infected_time=172.89473684210526, infected_time2=153.68421052631578 with result=0.0003088183810502601
# Completed simulation for infected_time=172.89473684210526, infected_time2=172.89473684210526 with result=0.5
# Completed simulation for infected_time=192.10526315789474, infected_time2=0.0 with result=8.862147356100193e-47
# Completed simulation for infected_time=192.10526315789474, infected_time2=19.210526315789473 with result=1.0866051866274956e-41
# Completed simulation for infected_time=192.10526315789474, infected_time2=38.421052631578945 with result=4.398233530007283e-36
# Completed simulation for infected_time=192.10526315789474, infected_time2=57.63157894736842 with result=2.828901010907676e-30
# Completed simulation for infected_time=192.10526315789474, infected_time2=96.05263157894737 with result=1.952246391640918e-19
# Completed simulation for infected_time=192.10526315789474, infected_time2=76.84210526315789 with result=1.2526085384620285e-24
# Completed simulation for infected_time=192.10526315789474, infected_time2=134.4736842105263 with result=1.1120677451089501e-10
# Completed simulation for infected_time=192.10526315789474, infected_time2=115.26315789473684 with result=8.583534537694728e-15
# Completed simulation for infected_time=192.10526315789474, infected_time2=153.68421052631578 with result=4.6846188970647124e-07
# Completed simulation for infected_time=192.10526315789474, infected_time2=172.89473684210526 with result=0.0008252281530686646
# Completed simulation for infected_time=192.10526315789474, infected_time2=192.10526315789474 with result=0.5
# Completed simulation for infected_time=211.3157894736842, infected_time2=0.0 with result=9.525059339505287e-48
# Completed simulation for infected_time=211.3157894736842, infected_time2=19.210526315789473 with result=8.26651292586804e-43
# Completed simulation for infected_time=211.3157894736842, infected_time2=38.421052631578945 with result=2.2906696916372964e-37
# Completed simulation for infected_time=211.3157894736842, infected_time2=76.84210526315789 with result=2.997769204106657e-26
# Completed simulation for infected_time=211.3157894736842, infected_time2=57.63157894736842 with result=9.940504082957953e-32
# Completed simulation for infected_time=211.3157894736842, infected_time2=96.05263157894737 with result=3.1639775704709603e-21
# Completed simulation for infected_time=211.3157894736842, infected_time2=115.26315789473684 with result=8.46613661840902e-17
# Completed simulation for infected_time=211.3157894736842, infected_time2=134.4736842105263 with result=6.551059902300785e-13
# Completed simulation for infected_time=211.3157894736842, infected_time2=153.68421052631578 with result=1.8294685784093037e-09
# Completed simulation for infected_time=211.3157894736842, infected_time2=172.89473684210526 with result=2.223993116683269e-06
# Completed simulation for infected_time=211.3157894736842, infected_time2=192.10526315789474 with result=0.0016293583216606415
# Completed simulation for infected_time=211.3157894736842, infected_time2=211.3157894736842 with result=0.5
# Completed simulation for infected_time=230.52631578947367, infected_time2=0.0 with result=1.451696284216909e-48
# Completed simulation for infected_time=230.52631578947367, infected_time2=19.210526315789473 with result=9.330156704984933e-44
# Completed simulation for infected_time=230.52631578947367, infected_time2=38.421052631578945 with result=1.8590986571597881e-38
# Completed simulation for infected_time=230.52631578947367, infected_time2=57.63157894736842 with result=5.728492454704205e-33
# Completed simulation for infected_time=230.52631578947367, infected_time2=76.84210526315789 with result=1.2370697704761336e-27
# Completed simulation for infected_time=230.52631578947367, infected_time2=96.05263157894737 with result=9.613267890298154e-23
# Completed simulation for infected_time=230.52631578947367, infected_time2=115.26315789473684 with result=1.9140262711261544e-18
# Completed simulation for infected_time=230.52631578947367, infected_time2=134.4736842105263 with result=1.0052756690048447e-14
# Completed simulation for infected_time=230.52631578947367, infected_time2=153.68421052631578 with result=1.892295533373367e-11
# Completed simulation for infected_time=230.52631578947367, infected_time2=172.89473684210526 with result=1.6765951902985082e-08
# Completed simulation for infected_time=230.52631578947367, infected_time2=192.10526315789474 with result=9.176178390629501e-06
# Completed simulation for infected_time=230.52631578947367, infected_time2=211.3157894736842 with result=0.00380624971075785
# Completed simulation for infected_time=230.52631578947367, infected_time2=230.52631578947367 with result=0.5
# Completed simulation for infected_time=249.73684210526315, infected_time2=0.0 with result=8.972905306491811e-36
# Completed simulation for infected_time=249.73684210526315, infected_time2=19.210526315789473 with result=2.473139411046211e-28
# Completed simulation for infected_time=249.73684210526315, infected_time2=38.421052631578945 with result=3.0977848144325034e-20
# Completed simulation for infected_time=249.73684210526315, infected_time2=57.63157894736842 with result=5.910478159947178e-12
# Completed simulation for infected_time=249.73684210526315, infected_time2=76.84210526315789 with result=0.0005283369217646799
# Completed simulation for infected_time=249.73684210526315, infected_time2=96.05263157894737 with result=0.9986487250352046
# Completed simulation for infected_time=249.73684210526315, infected_time2=115.26315789473684 with result=0.9999999894745132
# Completed simulation for infected_time=249.73684210526315, infected_time2=134.4736842105263 with result=0.9999999999988672
# Completed simulation for infected_time=249.73684210526315, infected_time2=153.68421052631578 with result=0.9999999999999992
# Completed simulation for infected_time=249.73684210526315, infected_time2=172.89473684210526 with result=1.0
# Completed simulation for infected_time=249.73684210526315, infected_time2=192.10526315789474 with result=1.0
# Completed simulation for infected_time=249.73684210526315, infected_time2=211.3157894736842 with result=1.0
# Completed simulation for infected_time=249.73684210526315, infected_time2=230.52631578947367 with result=1.0
# Completed simulation for infected_time=249.73684210526315, infected_time2=249.73684210526315 with result=0.5
# Completed simulation for infected_time=268.9473684210526, infected_time2=0.0 with result=9.701094626797085e-13
# Completed simulation for infected_time=268.9473684210526, infected_time2=19.210526315789473 with result=0.10418364219508051
# Completed simulation for infected_time=268.9473684210526, infected_time2=38.421052631578945 with result=0.9999999860264619
# Completed simulation for infected_time=268.9473684210526, infected_time2=57.63157894736842 with result=0.9999999999999998
# Completed simulation for infected_time=268.9473684210526, infected_time2=76.84210526315789 with result=1.0
# Completed simulation for infected_time=268.9473684210526, infected_time2=96.05263157894737 with result=1.0
# Completed simulation for infected_time=268.9473684210526, infected_time2=115.26315789473684 with result=1.0
# Completed simulation for infected_time=268.9473684210526, infected_time2=134.4736842105263 with result=1.0
# Completed simulation for infected_time=268.9473684210526, infected_time2=153.68421052631578 with result=1.0
# Completed simulation for infected_time=268.9473684210526, infected_time2=172.89473684210526 with result=1.0
# Completed simulation for infected_time=268.9473684210526, infected_time2=211.3157894736842 with result=1.0
# Completed simulation for infected_time=268.9473684210526, infected_time2=192.10526315789474 with result=1.0
# Completed simulation for infected_time=268.9473684210526, infected_time2=249.73684210526315 with result=1.0
# Completed simulation for infected_time=268.9473684210526, infected_time2=268.9473684210526 with result=0.49999999999999994
# Completed simulation for infected_time=268.9473684210526, infected_time2=230.52631578947367 with result=1.0
# Completed simulation for infected_time=288.1578947368421, infected_time2=0.0 with result=0.9950494490270942
# Completed simulation for infected_time=288.1578947368421, infected_time2=19.210526315789473 with result=0.9999999999999042
# Completed simulation for infected_time=288.1578947368421, infected_time2=38.421052631578945 with result=1.0
# Completed simulation for infected_time=288.1578947368421, infected_time2=57.63157894736842 with result=1.0
# Completed simulation for infected_time=288.1578947368421, infected_time2=76.84210526315789 with result=1.0
# Completed simulation for infected_time=288.1578947368421, infected_time2=96.05263157894737 with result=1.0
# Completed simulation for infected_time=288.1578947368421, infected_time2=134.4736842105263 with result=1.0
# Completed simulation for infected_time=288.1578947368421, infected_time2=115.26315789473684 with result=1.0
# Completed simulation for infected_time=288.1578947368421, infected_time2=153.68421052631578 with result=1.0
# Completed simulation for infected_time=288.1578947368421, infected_time2=172.89473684210526 with result=1.0
# Completed simulation for infected_time=288.1578947368421, infected_time2=192.10526315789474 with result=1.0
# Completed simulation for infected_time=288.1578947368421, infected_time2=211.3157894736842 with result=1.0
# Completed simulation for infected_time=288.1578947368421, infected_time2=230.52631578947367 with result=1.0
# Completed simulation for infected_time=288.1578947368421, infected_time2=249.73684210526315 with result=1.0
# Completed simulation for infected_time=288.1578947368421, infected_time2=268.9473684210526 with result=0.9999999999999378
# Completed simulation for infected_time=288.1578947368421, infected_time2=288.1578947368421 with result=0.5
# Completed simulation for infected_time=307.36842105263156, infected_time2=0.0 with result=0.9999999999880649
# Completed simulation for infected_time=307.36842105263156, infected_time2=19.210526315789473 with result=1.0
# Completed simulation for infected_time=307.36842105263156, infected_time2=38.421052631578945 with result=1.0
# Completed simulation for infected_time=307.36842105263156, infected_time2=57.63157894736842 with result=1.0
# Completed simulation for infected_time=307.36842105263156, infected_time2=76.84210526315789 with result=1.0
# Completed simulation for infected_time=307.36842105263156, infected_time2=96.05263157894737 with result=1.0
# Completed simulation for infected_time=307.36842105263156, infected_time2=115.26315789473684 with result=1.0
# Completed simulation for infected_time=307.36842105263156, infected_time2=134.4736842105263 with result=1.0
# Completed simulation for infected_time=307.36842105263156, infected_time2=153.68421052631578 with result=1.0
# Completed simulation for infected_time=307.36842105263156, infected_time2=172.89473684210526 with result=1.0
# Completed simulation for infected_time=307.36842105263156, infected_time2=192.10526315789474 with result=1.0
# Completed simulation for infected_time=307.36842105263156, infected_time2=211.3157894736842 with result=1.0
# Completed simulation for infected_time=307.36842105263156, infected_time2=230.52631578947367 with result=1.0
# Completed simulation for infected_time=307.36842105263156, infected_time2=249.73684210526315 with result=1.0
# Completed simulation for infected_time=307.36842105263156, infected_time2=268.9473684210526 with result=1.0
# Completed simulation for infected_time=307.36842105263156, infected_time2=288.1578947368421 with result=0.9999999924677029
# Completed simulation for infected_time=307.36842105263156, infected_time2=307.36842105263156 with result=0.5
# Completed simulation for infected_time=326.57894736842104, infected_time2=0.0 with result=0.9999999999999999
# Completed simulation for infected_time=326.57894736842104, infected_time2=19.210526315789473 with result=1.0
# Completed simulation for infected_time=326.57894736842104, infected_time2=38.421052631578945 with result=1.0
# Completed simulation for infected_time=326.57894736842104, infected_time2=57.63157894736842 with result=1.0
# Completed simulation for infected_time=326.57894736842104, infected_time2=76.84210526315789 with result=1.0
# Completed simulation for infected_time=326.57894736842104, infected_time2=96.05263157894737 with result=1.0
# Completed simulation for infected_time=326.57894736842104, infected_time2=115.26315789473684 with result=1.0
# Completed simulation for infected_time=326.57894736842104, infected_time2=134.4736842105263 with result=1.0
# Completed simulation for infected_time=326.57894736842104, infected_time2=153.68421052631578 with result=1.0
# Completed simulation for infected_time=326.57894736842104, infected_time2=172.89473684210526 with result=1.0
# Completed simulation for infected_time=326.57894736842104, infected_time2=192.10526315789474 with result=1.0
# Completed simulation for infected_time=326.57894736842104, infected_time2=211.3157894736842 with result=1.0
# Completed simulation for infected_time=326.57894736842104, infected_time2=230.52631578947367 with result=1.0
# Completed simulation for infected_time=326.57894736842104, infected_time2=249.73684210526315 with result=1.0
# Completed simulation for infected_time=326.57894736842104, infected_time2=268.9473684210526 with result=1.0
# Completed simulation for infected_time=326.57894736842104, infected_time2=288.1578947368421 with result=0.9999999999999182
# Completed simulation for infected_time=326.57894736842104, infected_time2=307.36842105263156 with result=0.9999966262298386
# Completed simulation for infected_time=326.57894736842104, infected_time2=326.57894736842104 with result=0.5
# Completed simulation for infected_time=345.7894736842105, infected_time2=0.0 with result=0.9999999999999917
# Completed simulation for infected_time=345.7894736842105, infected_time2=19.210526315789473 with result=1.0
# Completed simulation for infected_time=345.7894736842105, infected_time2=38.421052631578945 with result=1.0
# Completed simulation for infected_time=345.7894736842105, infected_time2=57.63157894736842 with result=1.0
# Completed simulation for infected_time=345.7894736842105, infected_time2=76.84210526315789 with result=1.0
# Completed simulation for infected_time=345.7894736842105, infected_time2=96.05263157894737 with result=1.0
# Completed simulation for infected_time=345.7894736842105, infected_time2=115.26315789473684 with result=1.0
# Completed simulation for infected_time=345.7894736842105, infected_time2=134.4736842105263 with result=1.0
# Completed simulation for infected_time=345.7894736842105, infected_time2=153.68421052631578 with result=1.0
# Completed simulation for infected_time=345.7894736842105, infected_time2=172.89473684210526 with result=1.0
# Completed simulation for infected_time=345.7894736842105, infected_time2=192.10526315789474 with result=1.0
# Completed simulation for infected_time=345.7894736842105, infected_time2=211.3157894736842 with result=1.0
# Completed simulation for infected_time=345.7894736842105, infected_time2=230.52631578947367 with result=1.0
# Completed simulation for infected_time=345.7894736842105, infected_time2=249.73684210526315 with result=1.0
# Completed simulation for infected_time=345.7894736842105, infected_time2=268.9473684210526 with result=1.0
# Completed simulation for infected_time=345.7894736842105, infected_time2=288.1578947368421 with result=0.9999999999901712
# Completed simulation for infected_time=345.7894736842105, infected_time2=307.36842105263156 with result=0.9989441417381925
# Completed simulation for infected_time=345.7894736842105, infected_time2=326.57894736842104 with result=0.0016835267060908517
# Completed simulation for infected_time=345.7894736842105, infected_time2=345.7894736842105 with result=0.5
# Completed simulation for infected_time=365.0, infected_time2=0.0 with result=0.5000000000000123
# Completed simulation for infected_time=365.0, infected_time2=19.210526315789473 with result=0.9999999999999708
# Completed simulation for infected_time=365.0, infected_time2=38.421052631578945 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=57.63157894736842 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=76.84210526315789 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=96.05263157894737 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=115.26315789473684 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=134.4736842105263 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=172.89473684210526 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=153.68421052631578 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=192.10526315789474 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=211.3157894736842 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=230.52631578947367 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=249.73684210526315 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=268.9473684210526 with result=0.99999999999903
# Completed simulation for infected_time=365.0, infected_time2=288.1578947368421 with result=0.004950550972906209
# Completed simulation for infected_time=365.0, infected_time2=307.36842105263156 with result=1.1935091504073296e-11
# Completed simulation for infected_time=365.0, infected_time2=326.57894736842104 with result=1.3338059442976526e-16
# Completed simulation for infected_time=365.0, infected_time2=345.7894736842105 with result=8.327534417413293e-15
# Completed simulation for infected_time=365.0, infected_time2=365.0 with result=0.5
#
# Raster process complete in 7495.1s!
# Max value: 1.0
# At infected_time = 249.73684210526315 and infected_time2 = 172.89473684210526
#
# Total execution time: 7495.12 seconds

# %%
param1_values = np.linspace(0, 365, 5)
param2_values = np.linspace(0, 365, 5)



model = Model(maturity=4/365, t = (0, 365 * 800), germination_time = 182.5, Bj = 0.2 / 365, infected_time=268.9473684210526, infected_time2=153.68421052631578)
graph_model = GraphModel(model)
# raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
graph_model.graph()
print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
# raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

# raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Success value is 0.7738980906394338. Final values are:
# Susceptible Juveniles: 0.8271
# Susceptible Vegetatives: 32.9949
# Susceptible Flowerings: 0.0000
# Infected Juveniles: 0.6454
# Infected Vegetatives: 8.4555
# Infected Flowerings: 0.0000
# Seeds: 13.1833
# Infected2 Juveniles: 0.0855
# Infected2 Vegetatives: 2.1387
# Infected2 Flowerings: 0.0000
# Evaluation (genotype1/genotype1+2):  0.7738980906394338
#
# Total execution time: 323.20 seconds

# %%
param1_values = np.linspace(0, 365, 5)
param2_values = np.linspace(0, 365, 5)



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 182.5, Bj = 0.2 / 365, infected_time=268.9473684210526, infected_time2=153.68421052631578, X_0= (5, 0, 0, 4.5, 0, 0, 0, .5, 0, 0))
graph_model = GraphModel(model)
# raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
graph_model.graph()
print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
# raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

# raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Success value is 0.8356955505256047. Final values are:
# Susceptible Juveniles: 0.8107
# Susceptible Vegetatives: 32.9297
# Susceptible Flowerings: 0.0000
# Infected Juveniles: 0.6869
# Infected Vegetatives: 9.0343
# Infected Flowerings: 0.0000
# Seeds: 13.2083
# Infected2 Juveniles: 0.0657
# Infected2 Vegetatives: 1.6363
# Infected2 Flowerings: 0.0000
# Evaluation (genotype1/genotype1+2):  0.8356955505256047
#
# Total execution time: 162.09 seconds
# /opt/anaconda3/envs/Bruns/lib/python3.13/site-packages/IPython/core/events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/Bruns/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from model_functions import Model, RasterModel, GraphModel
import numpy as np
import time

# %%
param1_values = np.linspace(300, 365, 8) #vertical axis
param2_values = np.linspace(250, 365, 10) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 302.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 8 processes...
# Total iterations: 80
# Progress: 0% complete
# Completed simulation for infected_time=309.2857142857143, infected_time2=275.55555555555554 with result=0.9999999999999999
# Completed simulation for infected_time=300.0, infected_time2=288.3333333333333 with result=0.9999965743812552
# Completed simulation for infected_time=300.0, infected_time2=250.0 with result=1.0
# Completed simulation for infected_time=300.0, infected_time2=275.55555555555554 with result=0.9999999999999001
# Completed simulation for infected_time=309.2857142857143, infected_time2=250.0 with result=1.0
# Completed simulation for infected_time=300.0, infected_time2=262.77777777777777 with result=1.0
# Completed simulation for infected_time=309.2857142857143, infected_time2=288.3333333333333 with result=0.9999999976618063
# Completed simulation for infected_time=309.2857142857143, infected_time2=262.77777777777777 with result=1.0
# Completed simulation for infected_time=309.2857142857143, infected_time2=301.1111111111111 with result=0.9990816600958239
# Completed simulation for infected_time=318.57142857142856, infected_time2=288.3333333333333 with result=0.99999999999337
# Completed simulation for infected_time=318.57142857142856, infected_time2=313.8888888888889 with result=0.9628203292663088
# Completed simulation for infected_time=318.57142857142856, infected_time2=275.55555555555554 with result=1.0
# Completed simulation for infected_time=327.8571428571429, infected_time2=250.0 with result=1.0
# Completed simulation for infected_time=318.57142857142856, infected_time2=301.1111111111111 with result=0.9999981643095237
# Completed simulation for infected_time=318.57142857142856, infected_time2=262.77777777777777 with result=1.0
# Completed simulation for infected_time=318.57142857142856, infected_time2=250.0 with result=1.0
# Completed simulation for infected_time=327.8571428571429, infected_time2=262.77777777777777 with result=1.0
# Completed simulation for infected_time=327.8571428571429, infected_time2=275.55555555555554 with result=1.0
# Completed simulation for infected_time=327.8571428571429, infected_time2=288.3333333333333 with result=0.9999999999999455
# Completed simulation for infected_time=327.8571428571429, infected_time2=301.1111111111111 with result=0.9999999880355669
# Completed simulation for infected_time=327.8571428571429, infected_time2=326.6666666666667 with result=0.6611671435192158
# Completed simulation for infected_time=327.8571428571429, infected_time2=313.8888888888889 with result=0.9998108840817812
# Completed simulation for infected_time=337.14285714285717, infected_time2=250.0 with result=1.0
# Completed simulation for infected_time=337.14285714285717, infected_time2=262.77777777777777 with result=1.0
# Completed simulation for infected_time=337.14285714285717, infected_time2=275.55555555555554 with result=1.0
# Completed simulation for infected_time=337.14285714285717, infected_time2=288.3333333333333 with result=0.9999999999999942
# Completed simulation for infected_time=337.14285714285717, infected_time2=301.1111111111111 with result=0.9999999987935381
# Completed simulation for infected_time=337.14285714285717, infected_time2=326.6666666666667 with result=0.9577968814716159
# Completed simulation for infected_time=337.14285714285717, infected_time2=313.8888888888889 with result=0.999981700101542
# Completed simulation for infected_time=346.42857142857144, infected_time2=250.0 with result=1.0
# Completed simulation for infected_time=346.42857142857144, infected_time2=262.77777777777777 with result=1.0
# Completed simulation for infected_time=346.42857142857144, infected_time2=275.55555555555554 with result=1.0
# Completed simulation for infected_time=346.42857142857144, infected_time2=288.3333333333333 with result=0.9999999999692232
# Completed simulation for infected_time=346.42857142857144, infected_time2=301.1111111111111 with result=0.9999857317614286
# Completed simulation for infected_time=346.42857142857144, infected_time2=313.8888888888889 with result=0.6656360376750149
# Completed simulation for infected_time=355.7142857142857, infected_time2=250.0 with result=1.0
# Completed simulation for infected_time=346.42857142857144, infected_time2=326.6666666666667 with result=0.0005492254958460432
# Completed simulation for infected_time=346.42857142857144, infected_time2=339.44444444444446 with result=7.840689689179213e-05
# Completed simulation for infected_time=355.7142857142857, infected_time2=262.77777777777777 with result=1.0
# Completed simulation for infected_time=355.7142857142857, infected_time2=275.55555555555554 with result=0.9999999999991932
# Completed simulation for infected_time=355.7142857142857, infected_time2=288.3333333333333 with result=0.9998784147689338
# Completed simulation for infected_time=355.7142857142857, infected_time2=301.1111111111111 with result=0.005727777087155152
# Completed simulation for infected_time=355.7142857142857, infected_time2=313.8888888888889 with result=1.6255708452265795e-07
# Completed simulation for infected_time=355.7142857142857, infected_time2=326.6666666666667 with result=1.0208519579008498e-10
# Completed simulation for infected_time=355.7142857142857, infected_time2=339.44444444444446 with result=1.5247252852815123e-11
# Completed simulation for infected_time=355.7142857142857, infected_time2=352.22222222222223 with result=0.0010016969685661752
# Completed simulation for infected_time=365.0, infected_time2=250.0 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=262.77777777777777 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=275.55555555555554 with result=0.9999992880672948
# Completed simulation for infected_time=365.0, infected_time2=288.3333333333333 with result=0.0039055667600224543
# Completed simulation for infected_time=365.0, infected_time2=301.1111111111111 with result=2.2352262809104387e-09
# Completed simulation for infected_time=365.0, infected_time2=313.8888888888889 with result=1.264594415146691e-13
# Completed simulation for infected_time=365.0, infected_time2=326.6666666666667 with result=1.2823230817104243e-16
# Completed simulation for infected_time=365.0, infected_time2=339.44444444444446 with result=1.8881756095192693e-17
# Completed simulation for infected_time=365.0, infected_time2=352.22222222222223 with result=1.2868852900542506e-10
# Completed simulation for infected_time=365.0, infected_time2=365.0 with result=0.5
#
# Raster process complete in 2004.3s!
# Max value: 1.0
# At infected_time = 300.0 and infected_time2 = 250.0
#
# Total execution time: 2004.36 seconds

# %%
param1_values = np.linspace(225, 275, 8) #vertical axis
param2_values = np.linspace(0, 250, 15) #horizontal axis


model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 302.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 8 processes...
# Total iterations: 120
# Progress: 0% complete
# Completed simulation for infected_time=225.0, infected_time2=89.28571428571429 with result=4.78070069942808e-24
# Completed simulation for infected_time=225.0, infected_time2=17.857142857142858 with result=6.913965696876425e-44
# Completed simulation for infected_time=225.0, infected_time2=35.714285714285715 with result=5.782160704300817e-39
# Completed simulation for infected_time=225.0, infected_time2=71.42857142857143 with result=8.852546922633649e-29
# Completed simulation for infected_time=225.0, infected_time2=125.0 with result=4.3977880049190673e-16
# Completed simulation for infected_time=225.0, infected_time2=0.0 with result=2.2954585460653953e-48
# Completed simulation for infected_time=225.0, infected_time2=53.57142857142857 with result=7.783145903922401e-34
# Completed simulation for infected_time=225.0, infected_time2=107.14285714285714 with result=8.323087954669518e-20
# Completed simulation for infected_time=225.0, infected_time2=142.85714285714286 with result=8.426087289344302e-13
# Completed simulation for infected_time=225.0, infected_time2=160.71428571428572 with result=7.52787869835553e-10
# Completed simulation for infected_time=225.0, infected_time2=196.42857142857144 with result=0.00012828770453769613
# Completed simulation for infected_time=232.14285714285714, infected_time2=0.0 with result=1.388886745979935e-48
# Completed simulation for infected_time=225.0, infected_time2=214.28571428571428 with result=0.03454295027647122
# Completed simulation for infected_time=225.0, infected_time2=178.57142857142858 with result=3.656218639943132e-07
# Completed simulation for infected_time=232.14285714285714, infected_time2=17.857142857142858 with result=3.9118253243074505e-44
# Completed simulation for infected_time=232.14285714285714, infected_time2=35.714285714285715 with result=3.039132222476022e-39
# Completed simulation for infected_time=232.14285714285714, infected_time2=71.42857142857143 with result=3.9885303818636666e-29
# Completed simulation for infected_time=232.14285714285714, infected_time2=53.57142857142857 with result=3.786645682746529e-34
# Completed simulation for infected_time=232.14285714285714, infected_time2=89.28571428571429 with result=2.0037645893389804e-24
# Completed simulation for infected_time=232.14285714285714, infected_time2=107.14285714285714 with result=3.272512788243233e-20
# Completed simulation for infected_time=232.14285714285714, infected_time2=125.0 with result=1.6168950828211172e-16
# Completed simulation for infected_time=232.14285714285714, infected_time2=142.85714285714286 with result=2.798251095964163e-13
# Completed simulation for infected_time=232.14285714285714, infected_time2=160.71428571428572 with result=2.254906595367297e-10
# Completed simulation for infected_time=232.14285714285714, infected_time2=178.57142857142858 with result=1.010030761070942e-07
# Completed simulation for infected_time=232.14285714285714, infected_time2=196.42857142857144 with result=3.307962974789015e-05
# Completed simulation for infected_time=232.14285714285714, infected_time2=214.28571428571428 with result=0.00850523819092716
# Completed simulation for infected_time=232.14285714285714, infected_time2=232.14285714285714 with result=0.5
# Completed simulation for infected_time=239.28571428571428, infected_time2=0.0 with result=2.4098940581264286e-47
# Completed simulation for infected_time=239.28571428571428, infected_time2=17.857142857142858 with result=1.2421348587071572e-42
# Completed simulation for infected_time=239.28571428571428, infected_time2=35.714285714285715 with result=1.8585299500606498e-37
# Completed simulation for infected_time=239.28571428571428, infected_time2=53.57142857142857 with result=4.5400019808047403e-32
# Completed simulation for infected_time=239.28571428571428, infected_time2=71.42857142857143 with result=9.20110692130151e-27
# Completed simulation for infected_time=239.28571428571428, infected_time2=89.28571428571429 with result=8.468338823328332e-22
# Completed simulation for infected_time=239.28571428571428, infected_time2=107.14285714285714 with result=2.388759533622519e-17
# Completed simulation for infected_time=239.28571428571428, infected_time2=125.0 with result=1.9363674655224443e-13
# Completed simulation for infected_time=239.28571428571428, infected_time2=142.85714285714286 with result=5.061807840218018e-10
# Completed simulation for infected_time=239.28571428571428, infected_time2=178.57142857142858 with result=0.0003620994467624846
# Completed simulation for infected_time=239.28571428571428, infected_time2=160.71428571428572 with result=5.671659383912304e-07
# Completed simulation for infected_time=239.28571428571428, infected_time2=214.28571428571428 with result=0.9853578844784951
# Completed simulation for infected_time=239.28571428571428, infected_time2=196.42857142857144 with result=0.15811001239127637
# Completed simulation for infected_time=239.28571428571428, infected_time2=232.14285714285714 with result=0.9998478929993979
# Completed simulation for infected_time=246.42857142857144, infected_time2=0.0 with result=1.965792125828077e-40
# Completed simulation for infected_time=246.42857142857144, infected_time2=35.714285714285715 with result=8.803521047770135e-28
# Completed simulation for infected_time=246.42857142857144, infected_time2=17.857142857142858 with result=2.1964217244571277e-34
# Completed simulation for infected_time=246.42857142857144, infected_time2=53.57142857142857 with result=6.0013273816920226e-21
# Completed simulation for infected_time=246.42857142857144, infected_time2=71.42857142857143 with result=2.949691376996043e-14
# Completed simulation for infected_time=246.42857142857144, infected_time2=89.28571428571429 with result=5.142646893975464e-08
# Completed simulation for infected_time=246.42857142857144, infected_time2=107.14285714285714 with result=0.01982845656696692
# Completed simulation for infected_time=246.42857142857144, infected_time2=125.0 with result=0.9977250532907307
# Completed simulation for infected_time=246.42857142857144, infected_time2=142.85714285714286 with result=0.9999993979318679
# Completed simulation for infected_time=246.42857142857144, infected_time2=160.71428571428572 with result=0.9999999992916215
# Completed simulation for infected_time=246.42857142857144, infected_time2=178.57142857142858 with result=0.9999999999979841
# Completed simulation for infected_time=246.42857142857144, infected_time2=196.42857142857144 with result=0.9999999999999903
# Completed simulation for infected_time=246.42857142857144, infected_time2=214.28571428571428 with result=1.0
# Completed simulation for infected_time=246.42857142857144, infected_time2=232.14285714285714 with result=1.0
# Completed simulation for infected_time=253.57142857142858, infected_time2=0.0 with result=2.1104224312624406e-30
# Completed simulation for infected_time=253.57142857142858, infected_time2=17.857142857142858 with result=1.3500911099485532e-22
# Completed simulation for infected_time=253.57142857142858, infected_time2=35.714285714285715 with result=3.57960219371139e-14
# Completed simulation for infected_time=253.57142857142858, infected_time2=53.57142857142857 with result=1.462487889650594e-05
# Completed simulation for infected_time=253.57142857142858, infected_time2=71.42857142857143 with result=0.9915420242401932
# Completed simulation for infected_time=253.57142857142858, infected_time2=89.28571428571429 with result=0.9999999938754396
# Completed simulation for infected_time=253.57142857142858, infected_time2=107.14285714285714 with result=0.999999999999906
# Completed simulation for infected_time=253.57142857142858, infected_time2=125.0 with result=1.0
# Completed simulation for infected_time=253.57142857142858, infected_time2=142.85714285714286 with result=1.0
# Completed simulation for infected_time=253.57142857142858, infected_time2=160.71428571428572 with result=1.0
# Completed simulation for infected_time=253.57142857142858, infected_time2=178.57142857142858 with result=1.0
# Completed simulation for infected_time=253.57142857142858, infected_time2=196.42857142857144 with result=1.0
# Completed simulation for infected_time=253.57142857142858, infected_time2=214.28571428571428 with result=1.0
# Completed simulation for infected_time=253.57142857142858, infected_time2=232.14285714285714 with result=1.0
# Completed simulation for infected_time=253.57142857142858, infected_time2=250.0 with result=0.9999999889746952
# Completed simulation for infected_time=260.7142857142857, infected_time2=0.0 with result=1.9526755085768736e-21
# Completed simulation for infected_time=260.7142857142857, infected_time2=17.857142857142858 with result=3.1446802660694774e-12
# Completed simulation for infected_time=260.7142857142857, infected_time2=35.714285714285715 with result=0.01650083502012716
# Completed simulation for infected_time=260.7142857142857, infected_time2=53.57142857142857 with result=0.9999972589268198
# Completed simulation for infected_time=260.7142857142857, infected_time2=71.42857142857143 with result=0.9999999999995869
# Completed simulation for infected_time=260.7142857142857, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=260.7142857142857, infected_time2=89.28571428571429 with result=1.0
# Completed simulation for infected_time=260.7142857142857, infected_time2=125.0 with result=1.0
# Completed simulation for infected_time=260.7142857142857, infected_time2=142.85714285714286 with result=1.0
# Completed simulation for infected_time=260.7142857142857, infected_time2=160.71428571428572 with result=1.0
# Completed simulation for infected_time=260.7142857142857, infected_time2=178.57142857142858 with result=1.0
# Completed simulation for infected_time=260.7142857142857, infected_time2=196.42857142857144 with result=1.0
# Completed simulation for infected_time=260.7142857142857, infected_time2=214.28571428571428 with result=1.0
# Completed simulation for infected_time=260.7142857142857, infected_time2=232.14285714285714 with result=1.0
# Completed simulation for infected_time=260.7142857142857, infected_time2=250.0 with result=1.0
# Completed simulation for infected_time=267.8571428571429, infected_time2=0.0 with result=8.448076692148552e-14
# Completed simulation for infected_time=267.8571428571429, infected_time2=17.857142857142858 with result=0.0016063467607970862
# Completed simulation for infected_time=267.8571428571429, infected_time2=35.714285714285715 with result=0.9999969900866305
# Completed simulation for infected_time=267.8571428571429, infected_time2=53.57142857142857 with result=0.9999999999999334
# Completed simulation for infected_time=267.8571428571429, infected_time2=71.42857142857143 with result=1.0
# Completed simulation for infected_time=267.8571428571429, infected_time2=89.28571428571429 with result=1.0
# Completed simulation for infected_time=267.8571428571429, infected_time2=125.0 with result=1.0
# Completed simulation for infected_time=267.8571428571429, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=267.8571428571429, infected_time2=142.85714285714286 with result=1.0
# Completed simulation for infected_time=267.8571428571429, infected_time2=160.71428571428572 with result=1.0
# Completed simulation for infected_time=267.8571428571429, infected_time2=178.57142857142858 with result=1.0
# Completed simulation for infected_time=267.8571428571429, infected_time2=196.42857142857144 with result=1.0
# Completed simulation for infected_time=267.8571428571429, infected_time2=214.28571428571428 with result=1.0
# Completed simulation for infected_time=267.8571428571429, infected_time2=232.14285714285714 with result=1.0
# Completed simulation for infected_time=267.8571428571429, infected_time2=250.0 with result=1.0
# Completed simulation for infected_time=275.0, infected_time2=0.0 with result=2.4731945921834997e-07
# Completed simulation for infected_time=275.0, infected_time2=17.857142857142858 with result=0.999264600759254
# Completed simulation for infected_time=275.0, infected_time2=35.714285714285715 with result=0.9999999999983215
# Completed simulation for infected_time=275.0, infected_time2=53.57142857142857 with result=1.0
# Completed simulation for infected_time=275.0, infected_time2=71.42857142857143 with result=1.0
# Completed simulation for infected_time=275.0, infected_time2=89.28571428571429 with result=1.0
# Completed simulation for infected_time=275.0, infected_time2=107.14285714285714 with result=1.0
# Completed simulation for infected_time=275.0, infected_time2=125.0 with result=1.0
# Completed simulation for infected_time=275.0, infected_time2=142.85714285714286 with result=1.0
# Completed simulation for infected_time=275.0, infected_time2=160.71428571428572 with result=1.0
# Completed simulation for infected_time=275.0, infected_time2=178.57142857142858 with result=1.0
# Completed simulation for infected_time=275.0, infected_time2=196.42857142857144 with result=1.0
# Completed simulation for infected_time=275.0, infected_time2=214.28571428571428 with result=1.0
# Completed simulation for infected_time=275.0, infected_time2=232.14285714285714 with result=1.0
# Completed simulation for infected_time=275.0, infected_time2=250.0 with result=1.0
#
# Raster process complete in 4392.6s!
# Max value: 1.0
# At infected_time = 246.42857142857144 and infected_time2 = 214.28571428571428
#
# Total execution time: 4392.64 seconds

# %%
param1_values = np.linspace(0, 365, 5)
param2_values = np.linspace(0, 365, 5)



model = Model(maturity=4/365, t = (0, 365 * 1600), germination_time = 302.5, Bj = 0.2 / 365, infected_time=346.42857142857144, infected_time2=313.8888888888889)
graph_model = GraphModel(model)
# raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
graph_model.graph()
print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
# raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

# raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Success value is 0.8863857690567346. Final values are:
# Susceptible Juveniles: 4.7345
# Susceptible Vegetatives: 23.1932
# Susceptible Flowerings: 0.0000
# Infected Juveniles: 1.9485
# Infected Vegetatives: 0.0178
# Infected Flowerings: 9.0199
# Seeds: 0.0008
# Infected2 Juveniles: 0.2224
# Infected2 Vegetatives: 0.7953
# Infected2 Flowerings: 0.1548
# Evaluation (genotype1/genotype1+2):  0.8863857690567346
#
# Total execution time: 689.18 seconds

# %%
param1_values = np.linspace(0, 365, 5)
param2_values = np.linspace(0, 365, 5)



model = Model(maturity=4/365, t = (0, 365 * 50), germination_time = 302.5, Bj = 0.2 / 365, infected_time=152.5, infected_time2=272.5)
graph_model = GraphModel(model)
# raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
graph_model.graph()
print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
# raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

# raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Success value is 6.942739299023189e-06. Final values are:
# Susceptible Juveniles: 9.4868
# Susceptible Vegetatives: 46.0574
# Susceptible Flowerings: 0.0000
# Infected Juveniles: 0.0000
# Infected Vegetatives: 0.0000
# Infected Flowerings: 0.0000
# Seeds: 0.0016
# Infected2 Juveniles: 2.8940
# Infected2 Vegetatives: 13.7158
# Infected2 Flowerings: 0.0000
# Evaluation (genotype1/genotype1+2):  6.942739299023189e-06
#
# Total execution time: 23.26 seconds

# %%
param1_values = np.linspace(0, 365, 5)
param2_values = np.linspace(0, 365, 5)



model = Model(maturity=2/365, t = (0, 365 * 50), germination_time = 302.5, Bj = 0.1 / 365, infected_time=152.5, infected_time2=272.5)
graph_model = GraphModel(model)
# raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
graph_model.graph()
print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
# raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

# raster_model.plot_heatmap()
# Out:
# Maturation rate: 2.0
# BetaJ:  0.10000000000000002
# BetaA:  0.025000000000000005
# Success value is 0.012435223272480622. Final values are:
# Susceptible Juveniles: 19.4331
# Susceptible Vegetatives: 44.7654
# Susceptible Flowerings: 0.0000
# Infected Juveniles: 0.0000
# Infected Vegetatives: 0.0000
# Infected Flowerings: 0.0000
# Seeds: 0.0016
# Infected2 Juveniles: 0.0009
# Infected2 Vegetatives: 0.0040
# Infected2 Flowerings: 0.0000
# Evaluation (genotype1/genotype1+2):  0.012435223272480622
#
# Total execution time: 20.94 seconds

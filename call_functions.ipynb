# %%
from model_functions import Model, RasterModel, GraphModel
import numpy as np
import time

# %%
param1_values = np.linspace(0, 365, 15) #vertical axis
param2_values = np.linspace(0, 365, 15) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 212.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 225
# Progress: 0% complete
# Progress: 2% complete (5/225) - Elapsed: 42.6s - Est. remaining: 1874.0s
# Progress: 4% complete (9/225) - Elapsed: 42.6s - Est. remaining: 1022.2s
# Progress: 6% complete (14/225) - Elapsed: 42.6s - Est. remaining: 641.9s
# Progress: 8% complete (18/225) - Elapsed: 43.6s - Est. remaining: 501.8s
# Progress: 10% complete (23/225) - Elapsed: 43.6s - Est. remaining: 383.2s
# Progress: 12% complete (27/225) - Elapsed: 43.6s - Est. remaining: 320.0s
# Progress: 14% complete (32/225) - Elapsed: 50.1s - Est. remaining: 302.4s
# Progress: 16% complete (36/225) - Elapsed: 50.1s - Est. remaining: 263.2s
# Progress: 18% complete (41/225) - Elapsed: 50.1s - Est. remaining: 225.0s
# Progress: 20% complete (45/225) - Elapsed: 50.1s - Est. remaining: 200.6s
# Progress: 22% complete (50/225) - Elapsed: 50.4s - Est. remaining: 176.4s
# Progress: 24% complete (54/225) - Elapsed: 50.4s - Est. remaining: 159.6s
# Progress: 26% complete (59/225) - Elapsed: 50.4s - Est. remaining: 141.8s
# Progress: 28% complete (63/225) - Elapsed: 50.4s - Est. remaining: 129.6s
# Progress: 30% complete (68/225) - Elapsed: 50.4s - Est. remaining: 116.3s
# Progress: 32% complete (72/225) - Elapsed: 50.4s - Est. remaining: 107.1s
# Progress: 34% complete (77/225) - Elapsed: 50.4s - Est. remaining: 96.9s

# %%
param1_values = np.linspace(0, 365, 15) #vertical axis
param2_values = np.linspace(0, 365, 15) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 242.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 225
# Progress: 0% complete
# Progress: 2% complete (5/225) - Elapsed: 579.7s - Est. remaining: 25505.1s
# Progress: 4% complete (9/225) - Elapsed: 579.7s - Est. remaining: 13911.9s
# Progress: 6% complete (14/225) - Elapsed: 579.7s - Est. remaining: 8736.3s
# Progress: 8% complete (18/225) - Elapsed: 579.7s - Est. remaining: 6666.1s
# Progress: 10% complete (23/225) - Elapsed: 579.7s - Est. remaining: 5090.9s
# Progress: 12% complete (27/225) - Elapsed: 579.7s - Est. remaining: 4250.8s
# Progress: 14% complete (32/225) - Elapsed: 596.5s - Est. remaining: 3597.4s
# Progress: 16% complete (36/225) - Elapsed: 596.5s - Est. remaining: 3131.4s
# Progress: 18% complete (41/225) - Elapsed: 596.5s - Est. remaining: 2676.8s
# Progress: 20% complete (45/225) - Elapsed: 596.5s - Est. remaining: 2385.8s
# Progress: 22% complete (50/225) - Elapsed: 600.9s - Est. remaining: 2103.1s
# Progress: 24% complete (54/225) - Elapsed: 600.9s - Est. remaining: 1902.8s
# Progress: 26% complete (59/225) - Elapsed: 600.9s - Est. remaining: 1690.6s
# Progress: 28% complete (63/225) - Elapsed: 600.9s - Est. remaining: 1545.1s
# Progress: 30% complete (68/225) - Elapsed: 600.9s - Est. remaining: 1387.4s
# Progress: 32% complete (72/225) - Elapsed: 600.9s - Est. remaining: 1276.9s
# Progress: 34% complete (77/225) - Elapsed: 600.9s - Est. remaining: 1155.0s
# Progress: 36% complete (81/225) - Elapsed: 1017.4s - Est. remaining: 1808.8s
# Progress: 38% complete (86/225) - Elapsed: 1017.4s - Est. remaining: 1644.5s
# Progress: 40% complete (90/225) - Elapsed: 1017.4s - Est. remaining: 1526.2s
# Progress: 42% complete (95/225) - Elapsed: 1048.3s - Est. remaining: 1434.6s
# Progress: 44% complete (99/225) - Elapsed: 1048.6s - Est. remaining: 1334.6s
# Progress: 46% complete (104/225) - Elapsed: 1048.6s - Est. remaining: 1220.0s
# Progress: 48% complete (108/225) - Elapsed: 1076.7s - Est. remaining: 1166.4s
# Progress: 50% complete (113/225) - Elapsed: 1091.0s - Est. remaining: 1081.3s
# Progress: 52% complete (117/225) - Elapsed: 1091.0s - Est. remaining: 1007.1s
# Progress: 54% complete (122/225) - Elapsed: 1106.9s - Est. remaining: 934.5s
# Progress: 56% complete (126/225) - Elapsed: 1520.0s - Est. remaining: 1194.3s
# Progress: 58% complete (131/225) - Elapsed: 1525.8s - Est. remaining: 1094.8s
# Progress: 60% complete (135/225) - Elapsed: 1525.8s - Est. remaining: 1017.2s
# Progress: 62% complete (140/225) - Elapsed: 1549.0s - Est. remaining: 940.5s
# Progress: 64% complete (144/225) - Elapsed: 1569.7s - Est. remaining: 882.9s
# Progress: 66% complete (149/225) - Elapsed: 1569.7s - Est. remaining: 800.6s
# Progress: 68% complete (153/225) - Elapsed: 1582.4s - Est. remaining: 744.6s
# Progress: 70% complete (158/225) - Elapsed: 1960.9s - Est. remaining: 831.5s
# Progress: 72% complete (162/225) - Elapsed: 2025.1s - Est. remaining: 787.6s
# Progress: 74% complete (167/225) - Elapsed: 2025.1s - Est. remaining: 703.3s
# Progress: 76% complete (171/225) - Elapsed: 2046.2s - Est. remaining: 646.2s
# Progress: 78% complete (176/225) - Elapsed: 2058.7s - Est. remaining: 573.2s
# Progress: 80% complete (180/225) - Elapsed: 2058.7s - Est. remaining: 514.7s
# Progress: 82% complete (185/225) - Elapsed: 2413.6s - Est. remaining: 521.8s
# Progress: 84% complete (189/225) - Elapsed: 2494.8s - Est. remaining: 475.2s
# Progress: 86% complete (194/225) - Elapsed: 2529.7s - Est. remaining: 404.2s
# Progress: 88% complete (198/225) - Elapsed: 2534.3s - Est. remaining: 345.6s
# Progress: 90% complete (203/225) - Elapsed: 2563.6s - Est. remaining: 277.8s
# Progress: 92% complete (207/225) - Elapsed: 2985.6s - Est. remaining: 259.6s
# Progress: 94% complete (212/225) - Elapsed: 3054.8s - Est. remaining: 187.3s
# Progress: 96% complete (216/225) - Elapsed: 3064.8s - Est. remaining: 127.7s
# Progress: 98% complete (221/225) - Elapsed: 3095.7s - Est. remaining: 56.0s
# Progress: 100% complete (225/225) - Elapsed: 3124.5s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# Raster process complete in 3124.8s!
# Max value: 0.8342229271199141
# At infected_time = 335.7142857142857 and infected_time2 = 330.0
#
# Total execution time: 3124.84 seconds

# %%
param1_values = np.linspace(0, 365, 15) #vertical axis
param2_values = np.linspace(0, 365, 15) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 272.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Progress: 70% complete (630/900) - Elapsed: 5941.6s - Est. remaining: 2546.4s
# Progress: 72% complete (648/900) - Elapsed: 6418.7s - Est. remaining: 2496.2s
# Progress: 74% complete (666/900) - Elapsed: 6553.9s - Est. remaining: 2302.7s
# Progress: 76% complete (684/900) - Elapsed: 6956.5s - Est. remaining: 2196.8s
# Progress: 78% complete (702/900) - Elapsed: 7381.5s - Est. remaining: 2082.0s
# Progress: 80% complete (720/900) - Elapsed: 7536.7s - Est. remaining: 1884.2s
# Progress: 82% complete (738/900) - Elapsed: 8020.0s - Est. remaining: 1760.5s
# Progress: 84% complete (756/900) - Elapsed: 8385.4s - Est. remaining: 1597.2s
# Progress: 86% complete (774/900) - Elapsed: 8855.3s - Est. remaining: 1441.6s
# Progress: 88% complete (792/900) - Elapsed: 9223.5s - Est. remaining: 1257.7s
# Progress: 90% complete (810/900) - Elapsed: 9410.7s - Est. remaining: 1045.6s
# Progress: 92% complete (828/900) - Elapsed: 9883.3s - Est. remaining: 859.4s
# Progress: 94% complete (846/900) - Elapsed: 10335.4s - Est. remaining: 659.7s
# Progress: 96% complete (864/900) - Elapsed: 10756.4s - Est. remaining: 448.2s
# Progress: 98% complete (882/900) - Elapsed: 11215.1s - Est. remaining: 228.9s
# Progress: 100% complete (900/900) - Elapsed: 11482.3s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# Raster process complete in 11482.8s!
# Max value: 0.9997957395553438
# At infected_time = 217.24137931034483 and infected_time2 = 200.0
#
# Total execution time: 11482.84 seconds

# %%
param1_values = np.linspace(0, 365, 5)
param2_values = np.linspace(0, 365, 5)



model = Model(maturity=2/365, t = (0, 365 * 50), germination_time = 302.5, Bj = 0.1 / 365, infected_time=152.5, infected_time2=272.5)
graph_model = GraphModel(model)
# raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
graph_model.graph()
print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
# raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

# raster_model.plot_heatmap()
# Out:
# Maturation rate: 2.0
# BetaJ:  0.10000000000000002
# BetaA:  0.025000000000000005
# Success value is 0.012435223272480622. Final values are:
# Susceptible Juveniles: 19.4331
# Susceptible Vegetatives: 44.7654
# Susceptible Flowerings: 0.0000
# Infected Juveniles: 0.0000
# Infected Vegetatives: 0.0000
# Infected Flowerings: 0.0000
# Seeds: 0.0016
# Infected2 Juveniles: 0.0009
# Infected2 Vegetatives: 0.0040
# Infected2 Flowerings: 0.0000
# Evaluation (genotype1/genotype1+2):  0.012435223272480622
#
# Total execution time: 20.94 seconds

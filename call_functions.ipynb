# %%
from model_functions import Model, RasterModel, GraphModel
import numpy as np
import time

# %%
param1_values = np.linspace(0, 365, 20)
param2_values = np.linspace(0, 365, 20)



model = Model(maturity=2/365, t = (0, 365 * 400), germination_time = 182.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 2.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 8 processes...
# Total iterations: 25
# Progress: 0% complete
# Completed simulation for infected_time=91.25, infected_time2=91.25 with result=0.5
# Completed simulation for infected_time=91.25, infected_time2=0.0 with result=3.361247873332381e-19
# Completed simulation for infected_time=0.0, infected_time2=0.0 with result=0.5
# Completed simulation for infected_time=0.0, infected_time2=91.25 with result=1.0
# Completed simulation for infected_time=0.0, infected_time2=273.75 with result=1.1090514421103753e-28
# Completed simulation for infected_time=91.25, infected_time2=182.5 with result=4.820132584013881e-43
# Completed simulation for infected_time=0.0, infected_time2=182.5 with result=1.8261783753832137e-30
# Completed simulation for infected_time=0.0, infected_time2=365.0 with result=0.4999999999999957
# Completed simulation for infected_time=182.5, infected_time2=182.5 with result=0.4999999999999999
# Completed simulation for infected_time=91.25, infected_time2=365.0 with result=3.36124787333232e-19
# Completed simulation for infected_time=182.5, infected_time2=0.0 with result=1.0
# Completed simulation for infected_time=273.75, infected_time2=0.0 with result=1.0
# Completed simulation for infected_time=182.5, infected_time2=273.75 with result=0.9999992926570453
# Completed simulation for infected_time=91.25, infected_time2=273.75 with result=1.4091723985763958e-41
# Completed simulation for infected_time=182.5, infected_time2=91.25 with result=1.0
# Completed simulation for infected_time=182.5, infected_time2=365.0 with result=1.0
# Completed simulation for infected_time=273.75, infected_time2=91.25 with result=1.0
# Completed simulation for infected_time=273.75, infected_time2=182.5 with result=7.073429546330437e-07
# Completed simulation for infected_time=273.75, infected_time2=273.75 with result=0.5
# Completed simulation for infected_time=365.0, infected_time2=182.5 with result=1.8261783753831983e-30
# Completed simulation for infected_time=365.0, infected_time2=91.25 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=0.0 with result=0.5000000000000042
# Completed simulation for infected_time=273.75, infected_time2=365.0 with result=1.0
# Completed simulation for infected_time=365.0, infected_time2=273.75 with result=1.1090514421104215e-28
# Completed simulation for infected_time=365.0, infected_time2=365.0 with result=0.49999999999999994
#
# Raster process complete in 1109.1s!
# Max value: 1.0
# At infected_time = 0.0 and infected_time2 = 91.25
#
# Total execution time: 1109.14 seconds

# %%
param1_values = np.linspace(0, 365, 5)
param2_values = np.linspace(0, 365, 5)



model = Model(maturity=2/365, t = (0, 365 * 5), germination_time = 182.5, Bj = 0.2 / 365, infected_time=91.25, infected_time2=91.25)
graph_model = GraphModel(model)
# raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
graph_model.graph()
print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
# raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

# raster_model.plot_heatmap()
# Out:
# Maturation rate: 2.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Success value is 0.5. Final values are:
# Susceptible Juveniles: 1.0754
# Susceptible Vegetatives: 5.1513
# Susceptible Flowerings: 0.0000
# Infected Juveniles: 0.0016
# Infected Vegetatives: 0.2565
# Infected Flowerings: 0.0000
# Seeds: 1.7834
# Infected2 Juveniles: 0.0016
# Infected2 Vegetatives: 0.2565
# Infected2 Flowerings: 0.0000
# Evaluation (genotype1/genotype1+2):  0.5
#
# Total execution time: 2.24 seconds

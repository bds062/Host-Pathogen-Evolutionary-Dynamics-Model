# %%
import sys
sys.path.append('../src')

from model import Model
from plot import RasterModel, GraphModel
import numpy as np
import time

# %%
param1_values = np.linspace(0, 365, 40) #vertical axis
param2_values = np.linspace(0, 365, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 62.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 104.8s - Est. remaining: 314.5s
# Progress: 50% complete (800/1600) - Elapsed: 415.8s - Est. remaining: 415.8s
# Progress: 75% complete (1200/1600) - Elapsed: 896.0s - Est. remaining: 298.7s
# Progress: 100% complete (1600/1600) - Elapsed: 1562.0s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 10
#   Flowering time: 93.59 days
#   Column sum: 0.5188
#
# Raster process complete in 1562.2s!
#
# Total execution time: 1562.25 seconds

# %%
param1_values = np.linspace(0, 365, 40) #vertical axis
param2_values = np.linspace(0, 365, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 92.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 119.9s - Est. remaining: 359.7s
# Progress: 50% complete (800/1600) - Elapsed: 422.0s - Est. remaining: 422.0s
# Progress: 75% complete (1200/1600) - Elapsed: 900.1s - Est. remaining: 300.0s
# Progress: 100% complete (1600/1600) - Elapsed: 1560.4s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 13
#   Flowering time: 121.67 days
#   Column sum: 0.5819
#
# Raster process complete in 1560.6s!
#
# Total execution time: 1560.65 seconds

# %%
param1_values = np.linspace(0, 365, 40) #vertical axis
param2_values = np.linspace(0, 365, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 122.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 120.4s - Est. remaining: 361.1s
# Progress: 50% complete (800/1600) - Elapsed: 419.1s - Est. remaining: 419.1s
# Progress: 75% complete (1200/1600) - Elapsed: 943.0s - Est. remaining: 314.3s

# %%
param1_values = np.linspace(0, 365, 40) #vertical axis
param2_values = np.linspace(0, 365, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 152.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 365.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 2% complete (32/1600) - Elapsed: 42.1s - Est. remaining: 2064.0s
# Progress: 4% complete (64/1600) - Elapsed: 47.3s - Est. remaining: 1134.1s
# Progress: 6% complete (96/1600) - Elapsed: 47.3s - Est. remaining: 740.4s
# Progress: 8% complete (128/1600) - Elapsed: 47.7s - Est. remaining: 548.0s
# Progress: 10% complete (160/1600) - Elapsed: 47.7s - Est. remaining: 428.9s
# Progress: 12% complete (192/1600) - Elapsed: 47.7s - Est. remaining: 349.5s
# Progress: 14% complete (224/1600) - Elapsed: 79.3s - Est. remaining: 487.1s
# Progress: 16% complete (256/1600) - Elapsed: 86.3s - Est. remaining: 453.0s
# Progress: 18% complete (288/1600) - Elapsed: 86.7s - Est. remaining: 395.1s
# Progress: 20% complete (320/1600) - Elapsed: 86.7s - Est. remaining: 346.9s
# ...

# %%
param1_values = np.linspace(0, 365, 40) #vertical axis
param2_values = np.linspace(0, 365, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 182.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 365.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 2% complete (32/1600) - Elapsed: 49.0s - Est. remaining: 2399.1s
# Progress: 4% complete (64/1600) - Elapsed: 49.4s - Est. remaining: 1185.2s
# Progress: 6% complete (96/1600) - Elapsed: 49.4s - Est. remaining: 773.7s
# Progress: 8% complete (128/1600) - Elapsed: 50.3s - Est. remaining: 578.4s
# Progress: 10% complete (160/1600) - Elapsed: 50.3s - Est. remaining: 452.6s
# Progress: 12% complete (192/1600) - Elapsed: 50.3s - Est. remaining: 368.8s
# Progress: 14% complete (224/1600) - Elapsed: 82.1s - Est. remaining: 504.4s
# Progress: 16% complete (256/1600) - Elapsed: 88.5s - Est. remaining: 464.7s
# Progress: 18% complete (288/1600) - Elapsed: 96.1s - Est. remaining: 438.0s
# Progress: 20% complete (320/1600) - Elapsed: 96.1s - Est. remaining: 384.5s
# ...

# %%
param1_values = np.linspace(0, 365, 40) #vertical axis
param2_values = np.linspace(0, 365, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 212.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 32.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 2% complete (32/1600) - Elapsed: 39.8s - Est. remaining: 1949.2s
# Progress: 4% complete (64/1600) - Elapsed: 40.3s - Est. remaining: 966.2s
# Progress: 6% complete (96/1600) - Elapsed: 48.8s - Est. remaining: 764.1s
# Progress: 8% complete (128/1600) - Elapsed: 48.8s - Est. remaining: 560.9s
# Progress: 10% complete (160/1600) - Elapsed: 48.8s - Est. remaining: 438.9s
# Progress: 12% complete (192/1600) - Elapsed: 48.8s - Est. remaining: 358.0s
# Progress: 14% complete (224/1600) - Elapsed: 76.7s - Est. remaining: 470.9s
# Progress: 16% complete (256/1600) - Elapsed: 82.3s - Est. remaining: 432.2s
# Progress: 18% complete (288/1600) - Elapsed: 90.4s - Est. remaining: 411.9s
# Progress: 20% complete (320/1600) - Elapsed: 90.4s - Est. remaining: 361.7s
# ...

# %%
param1_values = np.linspace(0, 365, 40) #vertical axis
param2_values = np.linspace(0, 365, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 242.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 32.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 2% complete (32/1600) - Elapsed: 42.3s - Est. remaining: 2071.6s
# Progress: 4% complete (64/1600) - Elapsed: 42.3s - Est. remaining: 1014.7s
# Progress: 6% complete (96/1600) - Elapsed: 48.9s - Est. remaining: 765.8s
# Progress: 8% complete (128/1600) - Elapsed: 48.9s - Est. remaining: 562.2s
# Progress: 10% complete (160/1600) - Elapsed: 48.9s - Est. remaining: 440.0s
# Progress: 12% complete (192/1600) - Elapsed: 48.9s - Est. remaining: 358.5s
# Progress: 14% complete (224/1600) - Elapsed: 76.1s - Est. remaining: 467.3s
# Progress: 16% complete (256/1600) - Elapsed: 83.7s - Est. remaining: 439.3s
# Progress: 18% complete (288/1600) - Elapsed: 91.9s - Est. remaining: 418.7s
# Progress: 20% complete (320/1600) - Elapsed: 91.9s - Est. remaining: 367.6s
# ...

# %%
param1_values = np.linspace(0, 365, 40) #vertical axis
param2_values = np.linspace(0, 365, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 272.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)

start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 32.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 2% complete (32/1600) - Elapsed: 39.4s - Est. remaining: 1928.6s
# Progress: 4% complete (64/1600) - Elapsed: 45.0s - Est. remaining: 1080.4s
# Progress: 6% complete (96/1600) - Elapsed: 45.9s - Est. remaining: 719.4s
# Progress: 8% complete (128/1600) - Elapsed: 46.6s - Est. remaining: 535.6s
# Progress: 10% complete (160/1600) - Elapsed: 46.6s - Est. remaining: 419.2s
# Progress: 12% complete (192/1600) - Elapsed: 47.9s - Est. remaining: 351.5s
# Progress: 14% complete (224/1600) - Elapsed: 77.1s - Est. remaining: 473.5s
# Progress: 16% complete (256/1600) - Elapsed: 84.5s - Est. remaining: 443.8s
# Progress: 18% complete (288/1600) - Elapsed: 89.8s - Est. remaining: 408.9s
# Progress: 20% complete (320/1600) - Elapsed: 89.8s - Est. remaining: 359.1s
# ...

# %%
param1_values = np.linspace(0, 365, 40) #vertical axis
param2_values = np.linspace(0, 365, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 302.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 32.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 2% complete (32/1600) - Elapsed: 46.8s - Est. remaining: 2292.3s
# Progress: 4% complete (64/1600) - Elapsed: 46.8s - Est. remaining: 1122.8s
# Progress: 6% complete (96/1600) - Elapsed: 46.8s - Est. remaining: 732.9s
# Progress: 8% complete (128/1600) - Elapsed: 47.8s - Est. remaining: 549.7s
# Progress: 10% complete (160/1600) - Elapsed: 47.8s - Est. remaining: 430.2s
# Progress: 12% complete (192/1600) - Elapsed: 47.8s - Est. remaining: 350.5s
# Progress: 14% complete (224/1600) - Elapsed: 76.2s - Est. remaining: 468.1s
# Progress: 16% complete (256/1600) - Elapsed: 83.7s - Est. remaining: 439.6s
# Progress: 18% complete (288/1600) - Elapsed: 89.7s - Est. remaining: 408.8s
# Progress: 20% complete (320/1600) - Elapsed: 89.7s - Est. remaining: 358.9s
# ...

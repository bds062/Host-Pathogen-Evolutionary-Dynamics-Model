# %%
import sys
sys.path.append('../src')

from model import Model
from plot import RasterModel, GraphModel
import numpy as np
import time

# %%
param1_values = np.linspace(0, 365, 15) #vertical axis
param2_values = np.linspace(0, 365, 15) #horizontal axis



model = Model(X_0 = (5, 0, 0, 5, 0, 0, 0, 0, 0, 0), t = (0, 365 * 400), germination_time = 212.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

# print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
raster_model.plot_fig1(
    germination_values=np.linspace(1, 364, 80),
    maturity_values=[2/365, 4/365, 8/365],
    bj_values=[0.1/365, 0.5/365],
    maturity_labels=["Slow (2 yr$^{-1}$)", "Intermediate (4 yr$^{-1}$)", "Fast (8 yr$^{-1}$)"],
    bj_labels=[r"$\beta_J$ = 0.1 yr$^{-1}$", r"$\beta_J$ = 0.5 yr$^{-1}$"],
    save_path="../../PubFigs/fig1.5.pdf",
)
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")
# Out:
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
#
# --- Panel A: Bj=0.100/yr, maturity=2.00/yr ---
#   25% (20/80) — 42.1s elapsed, ~126.2s remaining
#   50% (40/80) — 81.9s elapsed, ~81.9s remaining
#   75% (60/80) — 117.7s elapsed, ~39.2s remaining
#   100% (80/80) — 150.7s elapsed, ~0.0s remaining
#
# --- Panel A: Bj=0.100/yr, maturity=4.00/yr ---
#   25% (20/80) — 42.2s elapsed, ~126.6s remaining
#   50% (40/80) — 79.7s elapsed, ~79.7s remaining
#   75% (60/80) — 120.1s elapsed, ~40.0s remaining
#   100% (80/80) — 153.0s elapsed, ~0.0s remaining
#
# --- Panel A: Bj=0.100/yr, maturity=8.00/yr ---
#   25% (20/80) — 42.4s elapsed, ~127.2s remaining
#   50% (40/80) — 83.3s elapsed, ~83.3s remaining
#   75% (60/80) — 121.4s elapsed, ~40.5s remaining
#   100% (80/80) — 153.6s elapsed, ~0.0s remaining
#
# --- Panel B: Bj=0.500/yr, maturity=2.00/yr ---
#   25% (20/80) — 43.6s elapsed, ~130.7s remaining
#   50% (40/80) — 81.1s elapsed, ~81.1s remaining
#   75% (60/80) — 118.0s elapsed, ~39.3s remaining
#   100% (80/80) — 151.2s elapsed, ~0.0s remaining
#
# --- Panel B: Bj=0.500/yr, maturity=4.00/yr ---
#   25% (20/80) — 41.9s elapsed, ~125.8s remaining
#   50% (40/80) — 84.2s elapsed, ~84.2s remaining
#   75% (60/80) — 121.6s elapsed, ~40.5s remaining
#   100% (80/80) — 154.7s elapsed, ~0.0s remaining
#
# --- Panel B: Bj=0.500/yr, maturity=8.00/yr ---
#   25% (20/80) — 44.5s elapsed, ~133.4s remaining
#   50% (40/80) — 83.6s elapsed, ~83.6s remaining
#   75% (60/80) — 120.0s elapsed, ~40.0s remaining
#   100% (80/80) — 154.4s elapsed, ~0.0s remaining
#
# Figure saved to: ../../PubFigs/fig1.5.pdf
# Total execution time: 918.83 seconds

# %%
param1_values = np.linspace(0, 365, 15) #vertical axis
param2_values = np.linspace(0, 365, 15) #horizontal axis



model = Model(X_0 = (5, 0, 0, 5, 0, 0, 0, 0, 0, 0), t = (0, 365 * 400), germination_time = 212.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

# print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
raster_model.plot_fig2(
    infected_time_values=np.linspace(1, 364, 80),
    maturity_values=[2/365, 4/365, 8/365],
    germination_time_values=[92.5, 182.5, 272.5],       # early, mid, late season
    maturity_labels=["Slow (2 yr$^{-1}$)", "Intermediate (4 yr$^{-1}$)", "Fast (8 yr$^{-1}$)"],
    germination_labels=["Early germination (day 92.5)",
                        "Mid-season germination (day 182.5)",
                        "Late germination (day 272.5)"],
    save_path="../../PubFigs/fig2.5.pdf",
)
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")
# Out:
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
#
# --- Panel A: germination_time=92.5, maturity=2.00/yr ---
#   25% (20/80) — 40.3s elapsed, ~120.9s remaining
#   50% (40/80) — 82.5s elapsed, ~82.5s remaining
#   75% (60/80) — 124.1s elapsed, ~41.4s remaining
#   100% (80/80) — 161.1s elapsed, ~0.0s remaining
#
# --- Panel A: germination_time=92.5, maturity=4.00/yr ---
#   25% (20/80) — 51.3s elapsed, ~154.0s remaining
#   50% (40/80) — 92.5s elapsed, ~92.5s remaining
#   75% (60/80) — 135.2s elapsed, ~45.1s remaining
#   100% (80/80) — 174.8s elapsed, ~0.0s remaining
#
# --- Panel A: germination_time=92.5, maturity=8.00/yr ---
#   25% (20/80) — 51.3s elapsed, ~153.9s remaining
#   50% (40/80) — 93.2s elapsed, ~93.2s remaining
#   75% (60/80) — 137.0s elapsed, ~45.7s remaining
#   100% (80/80) — 174.4s elapsed, ~0.0s remaining
#
# --- Panel B: germination_time=182.5, maturity=2.00/yr ---
#   25% (20/80) — 46.8s elapsed, ~140.4s remaining
#   50% (40/80) — 90.3s elapsed, ~90.3s remaining
#   75% (60/80) — 131.3s elapsed, ~43.8s remaining
#   100% (80/80) — 164.4s elapsed, ~0.0s remaining
#
# --- Panel B: germination_time=182.5, maturity=4.00/yr ---
#   25% (20/80) — 47.9s elapsed, ~143.8s remaining
#   50% (40/80) — 88.1s elapsed, ~88.1s remaining
#   75% (60/80) — 128.2s elapsed, ~42.7s remaining
#   100% (80/80) — 164.6s elapsed, ~0.0s remaining
#
# --- Panel B: germination_time=182.5, maturity=8.00/yr ---
#   25% (20/80) — 46.1s elapsed, ~138.2s remaining
#   50% (40/80) — 86.2s elapsed, ~86.2s remaining
#   75% (60/80) — 128.3s elapsed, ~42.8s remaining
#   100% (80/80) — 165.1s elapsed, ~0.0s remaining
#
# --- Panel C: germination_time=272.5, maturity=2.00/yr ---
#   25% (20/80) — 45.7s elapsed, ~137.0s remaining
#   50% (40/80) — 86.3s elapsed, ~86.3s remaining
#   75% (60/80) — 124.9s elapsed, ~41.6s remaining
#   100% (80/80) — 160.0s elapsed, ~0.0s remaining
#
# --- Panel C: germination_time=272.5, maturity=4.00/yr ---
#   25% (20/80) — 45.3s elapsed, ~135.8s remaining
#   50% (40/80) — 84.9s elapsed, ~84.9s remaining
#   75% (60/80) — 125.6s elapsed, ~41.9s remaining
#   100% (80/80) — 163.6s elapsed, ~0.0s remaining
#
# --- Panel C: germination_time=272.5, maturity=8.00/yr ---
#   25% (20/80) — 46.2s elapsed, ~138.7s remaining
#   50% (40/80) — 89.3s elapsed, ~89.3s remaining
#   75% (60/80) — 128.6s elapsed, ~42.9s remaining
#   100% (80/80) — 166.1s elapsed, ~0.0s remaining
#
# Figure saved to: ../../PubFigs/fig2.5.pdf
# Total execution time: 1496.23 seconds

# %%
param1_values = np.linspace(0, 365, 15) #vertical axis
param2_values = np.linspace(0, 365, 15) #horizontal axis



model = Model(X_0 = (5, 0, 0, 5, 0, 0, 0, 0, 0, 0), t = (0, 365 * 400), germination_time = 212.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

# print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
raster_model.plot_fig3(save_path="../../PubFigs/fig3.pdf")
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")
# Out:
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
#
# Figure saved to: ../../PubFigs/fig3.pdf
# Total execution time: 0.45 seconds

# %%
import sys
sys.path.append('../src')

from model import Model
from plot import RasterModel, GraphModel
import numpy as np
import time

# %%
param1_values = np.linspace(0, 365, 15) #vertical axis
param2_values = np.linspace(0, 365, 15) #horizontal axis



model = Model(X_0 = (5, 0, 0, 5, 0, 0, 0, 0, 0, 0), t = (0, 365 * 400), germination_time = 212.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

# print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
raster_model.plot_fig1(
    germination_values=np.linspace(1, 364, 80),
    maturity_values=[2/365, 4/365, 8/365],
    bj_values=[0.1/365, 0.25/365, 0.5/365],
    maturity_labels=["Slow (2 yr$^{-1}$)", "Default (4 yr$^{-1}$)", "Fast (8 yr$^{-1}$)"],
    bj_labels=[r"$\beta_J$ = 0.10 yr$^{-1}$", r"$\beta_J$ = 0.25 yr$^{-1}$", r"$\beta_J$ = 0.5 yr$^{-1}$"],
    save_path="../../PubFigs/fig1.3.pdf",
)
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")
# Out:
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
#
# --- Panel A: Bj=0.100/yr, maturity=2.00/yr ---
#   25% (20/80) — 38.5s elapsed, ~115.6s remaining
#   50% (40/80) — 74.6s elapsed, ~74.6s remaining
#   75% (60/80) — 121.2s elapsed, ~40.4s remaining
#   100% (80/80) — 153.1s elapsed, ~0.0s remaining
#
# --- Panel A: Bj=0.100/yr, maturity=4.00/yr ---
#   25% (20/80) — 44.6s elapsed, ~133.9s remaining
#   50% (40/80) — 84.4s elapsed, ~84.4s remaining
#   75% (60/80) — 124.3s elapsed, ~41.4s remaining
#   100% (80/80) — 158.5s elapsed, ~0.0s remaining
#
# --- Panel A: Bj=0.100/yr, maturity=8.00/yr ---
#   25% (20/80) — 45.4s elapsed, ~136.2s remaining
#   50% (40/80) — 87.2s elapsed, ~87.2s remaining
#   75% (60/80) — 127.9s elapsed, ~42.6s remaining
#   100% (80/80) — 161.7s elapsed, ~0.0s remaining
#
# --- Panel B: Bj=0.250/yr, maturity=2.00/yr ---
#   25% (20/80) — 47.8s elapsed, ~143.3s remaining
#   50% (40/80) — 90.8s elapsed, ~90.8s remaining
#   75% (60/80) — 128.6s elapsed, ~42.9s remaining
#   100% (80/80) — 158.7s elapsed, ~0.0s remaining
#
# --- Panel B: Bj=0.250/yr, maturity=4.00/yr ---
#   25% (20/80) — 42.2s elapsed, ~126.7s remaining
#   50% (40/80) — 80.4s elapsed, ~80.4s remaining
#   75% (60/80) — 118.5s elapsed, ~39.5s remaining
#   100% (80/80) — 148.6s elapsed, ~0.0s remaining
#
# --- Panel B: Bj=0.250/yr, maturity=8.00/yr ---
#   25% (20/80) — 41.4s elapsed, ~124.3s remaining
#   50% (40/80) — 78.4s elapsed, ~78.4s remaining
#   75% (60/80) — 115.7s elapsed, ~38.6s remaining
#   100% (80/80) — 146.3s elapsed, ~0.0s remaining
#
# --- Panel C: Bj=0.500/yr, maturity=2.00/yr ---
#   25% (20/80) — 41.2s elapsed, ~123.5s remaining
#   50% (40/80) — 76.8s elapsed, ~76.8s remaining
#   75% (60/80) — 113.9s elapsed, ~38.0s remaining
#   100% (80/80) — 144.1s elapsed, ~0.0s remaining
#
# --- Panel C: Bj=0.500/yr, maturity=4.00/yr ---
#   25% (20/80) — 41.6s elapsed, ~124.7s remaining
#   50% (40/80) — 77.8s elapsed, ~77.8s remaining
#   75% (60/80) — 112.7s elapsed, ~37.6s remaining
#   100% (80/80) — 144.3s elapsed, ~0.0s remaining
#
# --- Panel C: Bj=0.500/yr, maturity=8.00/yr ---
#   25% (20/80) — 41.1s elapsed, ~123.4s remaining
#   50% (40/80) — 79.0s elapsed, ~79.0s remaining
#   75% (60/80) — 114.1s elapsed, ~38.0s remaining
#   100% (80/80) — 145.3s elapsed, ~0.0s remaining
#
# Figure saved to: ../../PubFigs/fig1.3.pdf
# Total execution time: 1362.04 seconds

# %%
param1_values = np.linspace(0, 365, 15) #vertical axis
param2_values = np.linspace(0, 365, 15) #horizontal axis



model = Model(X_0 = (5, 0, 0, 5, 0, 0, 0, 0, 0, 0), t = (0, 365 * 400), germination_time = 212.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

# print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
raster_model.plot_fig2(
    infected_time_values=np.linspace(1, 364, 80),
    maturity_values=[2/365, 4/365, 8/365],
    germination_time_values=[92.5, 182.5, 272.5],       # early, mid, late season
    maturity_labels=["Slow (2 yr$^{-1}$)", "Default (4 yr$^{-1}$)", "Fast (8 yr$^{-1}$)"],
    germination_labels=["Early germination (day 92.5)",
                        "Mid-season germination (day 182.5)",
                        "Late germination (day 272.5)"],
    save_path="../../PubFigs/fig2.3.pdf",
)
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")
# Out:
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
#
# --- Panel A: germination_time=92.5, maturity=2.00/yr ---
#   25% (20/80) — 42.0s elapsed, ~125.9s remaining
#   50% (40/80) — 80.1s elapsed, ~80.1s remaining
#   75% (60/80) — 118.2s elapsed, ~39.4s remaining
#   100% (80/80) — 149.9s elapsed, ~0.0s remaining
#
# --- Panel A: germination_time=92.5, maturity=4.00/yr ---
#   25% (20/80) — 43.0s elapsed, ~129.0s remaining
#   50% (40/80) — 82.6s elapsed, ~82.6s remaining
#   75% (60/80) — 122.3s elapsed, ~40.8s remaining
#   100% (80/80) — 155.5s elapsed, ~0.0s remaining
#
# --- Panel A: germination_time=92.5, maturity=8.00/yr ---
#   25% (20/80) — 43.3s elapsed, ~130.0s remaining
#   50% (40/80) — 81.5s elapsed, ~81.5s remaining
#   75% (60/80) — 121.3s elapsed, ~40.4s remaining
#   100% (80/80) — 155.9s elapsed, ~0.0s remaining
#
# --- Panel B: germination_time=182.5, maturity=2.00/yr ---
#   25% (20/80) — 38.8s elapsed, ~116.3s remaining
#   50% (40/80) — 77.7s elapsed, ~77.7s remaining
#   75% (60/80) — 117.0s elapsed, ~39.0s remaining
#   100% (80/80) — 147.4s elapsed, ~0.0s remaining
#
# --- Panel B: germination_time=182.5, maturity=4.00/yr ---
#   25% (20/80) — 42.4s elapsed, ~127.2s remaining
#   50% (40/80) — 81.8s elapsed, ~81.8s remaining
#   75% (60/80) — 121.3s elapsed, ~40.4s remaining
#   100% (80/80) — 154.8s elapsed, ~0.0s remaining
#
# --- Panel B: germination_time=182.5, maturity=8.00/yr ---
#   25% (20/80) — 43.2s elapsed, ~129.7s remaining
#   50% (40/80) — 82.5s elapsed, ~82.5s remaining
#   75% (60/80) — 123.5s elapsed, ~41.2s remaining
#   100% (80/80) — 157.9s elapsed, ~0.0s remaining
#
# --- Panel C: germination_time=272.5, maturity=2.00/yr ---
#   25% (20/80) — 42.6s elapsed, ~127.8s remaining
#   50% (40/80) — 78.9s elapsed, ~78.9s remaining
#   75% (60/80) — 117.5s elapsed, ~39.2s remaining
#   100% (80/80) — 150.0s elapsed, ~0.0s remaining
#
# --- Panel C: germination_time=272.5, maturity=4.00/yr ---
#   25% (20/80) — 43.0s elapsed, ~128.9s remaining
#   50% (40/80) — 81.8s elapsed, ~81.8s remaining
#   75% (60/80) — 120.8s elapsed, ~40.3s remaining
#   100% (80/80) — 155.4s elapsed, ~0.0s remaining
#
# --- Panel C: germination_time=272.5, maturity=8.00/yr ---
#   25% (20/80) — 42.9s elapsed, ~128.7s remaining
#   50% (40/80) — 83.2s elapsed, ~83.2s remaining
#   75% (60/80) — 121.0s elapsed, ~40.3s remaining
#   100% (80/80) — 156.2s elapsed, ~0.0s remaining
#
# Figure saved to: ../../PubFigs/fig2.3.pdf
# Total execution time: 1384.15 seconds

# %%
param1_values = np.linspace(0, 365, 15) #vertical axis
param2_values = np.linspace(0, 365, 15) #horizontal axis



model = Model(X_0 = (5, 0, 0, 5, 0, 0, 0, 0, 0, 0), t = (0, 365 * 400), germination_time = 212.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

# print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
raster_model.plot_fig3(save_path="../../PubFigs/fig3.pdf")
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")
# Out:
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
#
# Figure saved to: ../../PubFigs/fig3.pdf
# Total execution time: 0.45 seconds

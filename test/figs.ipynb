# %%
import sys
sys.path.append('../src')

from model import Model
from plot import RasterModel, GraphModel
import numpy as np
import time

# %%
param1_values = np.linspace(0, 365, 15) #vertical axis
param2_values = np.linspace(0, 365, 15) #horizontal axis



model = Model(X_0 = (5, 0, 0, 5, 0, 0, 0, 0, 0, 0), t = (0, 365 * 400), germination_time = 212.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

# print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
raster_model.plot_fig1(
    germination_values=np.linspace(1, 364, 80),
    maturity_values=[2/365, 4/365, 8/365],
    bj_values=[0.1/365, 0.5/365],
    maturity_labels=["Slow (2 yr$^{-1}$)", "Default (4 yr$^{-1}$)", "Fast (8 yr$^{-1}$)"],
    bj_labels=[r"$\beta_J$ = 0.1 yr$^{-1}$", r"$\beta_J$ = 0.5 yr$^{-1}$"],
    save_path="../../PubFigs/fig1.4.pdf",
)
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")
# Out:
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
#
# --- Panel A: Bj=0.100/yr, maturity=2.00/yr ---
#   25% (20/80) — 31.8s elapsed, ~95.5s remaining
#   50% (40/80) — 63.3s elapsed, ~63.3s remaining
#   75% (60/80) — 95.0s elapsed, ~31.7s remaining
#   100% (80/80) — 124.4s elapsed, ~0.0s remaining
#
# --- Panel A: Bj=0.100/yr, maturity=4.00/yr ---
#   25% (20/80) — 43.1s elapsed, ~129.4s remaining
#   50% (40/80) — 80.9s elapsed, ~80.9s remaining
#   75% (60/80) — 120.5s elapsed, ~40.2s remaining
#   100% (80/80) — 149.6s elapsed, ~0.0s remaining
#
# --- Panel A: Bj=0.100/yr, maturity=8.00/yr ---
#   25% (20/80) — 42.7s elapsed, ~128.0s remaining
#   50% (40/80) — 82.6s elapsed, ~82.6s remaining
#   75% (60/80) — 121.7s elapsed, ~40.6s remaining
#   100% (80/80) — 152.4s elapsed, ~0.0s remaining
#
# --- Panel B: Bj=0.500/yr, maturity=2.00/yr ---
#   25% (20/80) — 41.7s elapsed, ~125.0s remaining
#   50% (40/80) — 78.9s elapsed, ~78.9s remaining
#   75% (60/80) — 117.7s elapsed, ~39.2s remaining
#   100% (80/80) — 146.8s elapsed, ~0.0s remaining
#
# --- Panel B: Bj=0.500/yr, maturity=4.00/yr ---
#   25% (20/80) — 43.7s elapsed, ~131.1s remaining
#   50% (40/80) — 83.0s elapsed, ~83.0s remaining
#   75% (60/80) — 121.5s elapsed, ~40.5s remaining
#   100% (80/80) — 149.1s elapsed, ~0.0s remaining
#
# --- Panel B: Bj=0.500/yr, maturity=8.00/yr ---
#   25% (20/80) — 42.3s elapsed, ~126.8s remaining
#   50% (40/80) — 81.8s elapsed, ~81.8s remaining
#   75% (60/80) — 120.9s elapsed, ~40.3s remaining
#   100% (80/80) — 150.0s elapsed, ~0.0s remaining
#
# Figure saved to: ../../PubFigs/fig1.4.pdf
# Total execution time: 873.70 seconds

# %%
param1_values = np.linspace(0, 365, 15) #vertical axis
param2_values = np.linspace(0, 365, 15) #horizontal axis



model = Model(X_0 = (5, 0, 0, 5, 0, 0, 0, 0, 0, 0), t = (0, 365 * 400), germination_time = 212.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

# print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
raster_model.plot_fig2(
    infected_time_values=np.linspace(1, 364, 80),
    maturity_values=[2/365, 4/365, 8/365],
    germination_time_values=[92.5, 182.5, 272.5],       # early, mid, late season
    maturity_labels=["Slow (2 yr$^{-1}$)", "Default (4 yr$^{-1}$)", "Fast (8 yr$^{-1}$)"],
    germination_labels=["Early germination (day 92.5)",
                        "Mid-season germination (day 182.5)",
                        "Late germination (day 272.5)"],
    save_path="../../PubFigs/fig2.4.pdf",
)
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")
# Out:
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
#
# --- Panel A: germination_time=92.5, maturity=2.00/yr ---
#   25% (20/80) — 43.2s elapsed, ~129.6s remaining
#   50% (40/80) — 83.0s elapsed, ~83.0s remaining
#   75% (60/80) — 123.1s elapsed, ~41.0s remaining
#   100% (80/80) — 152.7s elapsed, ~0.0s remaining
#
# --- Panel A: germination_time=92.5, maturity=4.00/yr ---
#   25% (20/80) — 45.8s elapsed, ~137.5s remaining
#   50% (40/80) — 86.4s elapsed, ~86.4s remaining
#   75% (60/80) — 127.7s elapsed, ~42.6s remaining
#   100% (80/80) — 158.6s elapsed, ~0.0s remaining
#
# --- Panel A: germination_time=92.5, maturity=8.00/yr ---
#   25% (20/80) — 46.2s elapsed, ~138.7s remaining
#   50% (40/80) — 86.3s elapsed, ~86.3s remaining
#   75% (60/80) — 128.7s elapsed, ~42.9s remaining
#   100% (80/80) — 161.3s elapsed, ~0.0s remaining
#
# --- Panel B: germination_time=182.5, maturity=2.00/yr ---
#   25% (20/80) — 41.9s elapsed, ~125.6s remaining
#   50% (40/80) — 82.1s elapsed, ~82.1s remaining
#   75% (60/80) — 123.8s elapsed, ~41.3s remaining
#   100% (80/80) — 153.0s elapsed, ~0.0s remaining
#
# --- Panel B: germination_time=182.5, maturity=4.00/yr ---
#   25% (20/80) — 44.7s elapsed, ~134.0s remaining
#   50% (40/80) — 85.3s elapsed, ~85.3s remaining
#   75% (60/80) — 127.0s elapsed, ~42.3s remaining
#   100% (80/80) — 159.2s elapsed, ~0.0s remaining
#
# --- Panel B: germination_time=182.5, maturity=8.00/yr ---
#   25% (20/80) — 45.8s elapsed, ~137.4s remaining
#   50% (40/80) — 87.5s elapsed, ~87.5s remaining
#   75% (60/80) — 129.9s elapsed, ~43.3s remaining
#   100% (80/80) — 162.3s elapsed, ~0.0s remaining
#
# --- Panel C: germination_time=272.5, maturity=2.00/yr ---
#   25% (20/80) — 46.7s elapsed, ~140.2s remaining
#   50% (40/80) — 85.2s elapsed, ~85.2s remaining
#   75% (60/80) — 125.9s elapsed, ~42.0s remaining
#   100% (80/80) — 155.9s elapsed, ~0.0s remaining
#
# --- Panel C: germination_time=272.5, maturity=4.00/yr ---
#   25% (20/80) — 46.7s elapsed, ~140.2s remaining
#   50% (40/80) — 87.3s elapsed, ~87.3s remaining
#   75% (60/80) — 129.1s elapsed, ~43.0s remaining
#   100% (80/80) — 161.8s elapsed, ~0.0s remaining
#
# --- Panel C: germination_time=272.5, maturity=8.00/yr ---
#   25% (20/80) — 46.0s elapsed, ~137.9s remaining
#   50% (40/80) — 87.8s elapsed, ~87.8s remaining
#   75% (60/80) — 128.4s elapsed, ~42.8s remaining
#   100% (80/80) — 161.1s elapsed, ~0.0s remaining
#
# Figure saved to: ../../PubFigs/fig2.4.pdf
# Total execution time: 1427.61 seconds

# %%
param1_values = np.linspace(0, 365, 15) #vertical axis
param2_values = np.linspace(0, 365, 15) #horizontal axis



model = Model(X_0 = (5, 0, 0, 5, 0, 0, 0, 0, 0, 0), t = (0, 365 * 400), germination_time = 212.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

# print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
raster_model.plot_fig3(save_path="../../PubFigs/fig3.pdf")
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")
# Out:
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
#
# Figure saved to: ../../PubFigs/fig3.pdf
# Total execution time: 0.45 seconds

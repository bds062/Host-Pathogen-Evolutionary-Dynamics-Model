# %%
import sys
sys.path.append('../src')

from model import Model
from plot import RasterModel, GraphModel
import numpy as np
import time

# %%
param1_values = np.linspace(83, 103, 40) #vertical axis
param2_values = np.linspace(83, 103, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 62.5, Bj = 0.4 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")
    
raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.4000000000000001
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 197.2s - Est. remaining: 591.7s
# Progress: 50% complete (800/1600) - Elapsed: 494.0s - Est. remaining: 494.0s
# Progress: 75% complete (1200/1600) - Elapsed: 970.4s - Est. remaining: 323.5s
# Progress: 100% complete (1600/1600) - Elapsed: 1638.5s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 23
#   Flowering time: 94.79 days
#   Column sum: 7.8999
#
# Raster process complete in 1638.6s!
#
# Total execution time: 1638.63 seconds

# %%
param1_values = np.linspace(111, 131, 40) #vertical axis
param2_values = np.linspace(111, 131, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 92.5, Bj = 0.4 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.4000000000000001
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 124.3s - Est. remaining: 372.8s
# Progress: 50% complete (800/1600) - Elapsed: 426.3s - Est. remaining: 426.3s
# Progress: 75% complete (1200/1600) - Elapsed: 927.6s - Est. remaining: 309.2s
# Progress: 100% complete (1600/1600) - Elapsed: 1617.7s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 27
#   Flowering time: 124.85 days
#   Column sum: 7.9172
#
# Raster process complete in 1618.0s!
#
# Total execution time: 1617.98 seconds

# %%
param1_values = np.linspace(144, 164, 40) #vertical axis
param2_values = np.linspace(144, 164, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 122.5, Bj = 0.4 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.4000000000000001
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 122.4s - Est. remaining: 367.1s
# Progress: 50% complete (800/1600) - Elapsed: 436.0s - Est. remaining: 436.0s
# Progress: 75% complete (1200/1600) - Elapsed: 922.7s - Est. remaining: 307.6s
# Progress: 100% complete (1600/1600) - Elapsed: 1593.1s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 21
#   Flowering time: 154.77 days
#   Column sum: 7.8158
#
# Raster process complete in 1593.2s!
#
# Total execution time: 1593.21 seconds

# %%
param1_values = np.linspace(177, 197, 40) #vertical axis
param2_values = np.linspace(177, 197, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 152.5, Bj = 0.4 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.4000000000000001
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 114.0s - Est. remaining: 342.0s
# Progress: 50% complete (800/1600) - Elapsed: 409.7s - Est. remaining: 409.7s
# Progress: 75% complete (1200/1600) - Elapsed: 889.1s - Est. remaining: 296.4s
# Progress: 100% complete (1600/1600) - Elapsed: 1549.0s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 18
#   Flowering time: 186.23 days
#   Column sum: 7.8044
#
# Raster process complete in 1549.1s!
#
# Total execution time: 1549.14 seconds

# %%
param1_values = np.linspace(205, 225, 40) #vertical axis
param2_values = np.linspace(205, 225, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 182.5, Bj = 0.4 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.4000000000000001
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 133.4s - Est. remaining: 400.2s
# Progress: 50% complete (800/1600) - Elapsed: 448.5s - Est. remaining: 448.5s
# Progress: 75% complete (1200/1600) - Elapsed: 973.2s - Est. remaining: 324.4s
# Progress: 100% complete (1600/1600) - Elapsed: 2138.5s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 22
#   Flowering time: 216.28 days
#   Column sum: 7.7936
#
# Raster process complete in 2139.1s!
#
# Total execution time: 2139.10 seconds

# %%
param1_values = np.linspace(233, 253, 40) #vertical axis
param2_values = np.linspace(233, 253, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 212.5, Bj = 0.4 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.4000000000000001
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 228.9s - Est. remaining: 686.8s
# Progress: 50% complete (800/1600) - Elapsed: 825.7s - Est. remaining: 825.7s
# Progress: 75% complete (1200/1600) - Elapsed: 1805.4s - Est. remaining: 601.8s
# Progress: 100% complete (1600/1600) - Elapsed: 3113.7s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 26
#   Flowering time: 246.33 days
#   Column sum: 7.7775
#
# Raster process complete in 3113.9s!
#
# Total execution time: 3113.86 seconds

# %%
param1_values = np.linspace(266, 286, 40) #vertical axis
param2_values = np.linspace(266, 286, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 242.5, Bj = 0.4 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.4000000000000001
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 217.7s - Est. remaining: 653.2s
# Progress: 50% complete (800/1600) - Elapsed: 789.9s - Est. remaining: 789.9s
# Progress: 75% complete (1200/1600) - Elapsed: 1716.4s - Est. remaining: 572.1s
# Progress: 100% complete (1600/1600) - Elapsed: 2934.5s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 18
#   Flowering time: 275.23 days
#   Column sum: 7.6108
#
# Raster process complete in 2934.6s!
#
# Total execution time: 2934.63 seconds

# %%
param1_values = np.linspace(294, 314, 40) #vertical axis
param2_values = np.linspace(294, 314, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 272.5, Bj = 0.4 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)

start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.4000000000000001
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 218.7s - Est. remaining: 656.0s
# Progress: 50% complete (800/1600) - Elapsed: 795.6s - Est. remaining: 795.6s
# Progress: 75% complete (1200/1600) - Elapsed: 1747.8s - Est. remaining: 582.6s
# Progress: 100% complete (1600/1600) - Elapsed: 3027.2s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 22
#   Flowering time: 305.28 days
#   Column sum: 7.7050
#
# Raster process complete in 3027.6s!
#
# Total execution time: 3027.58 seconds

# %%
param1_values = np.linspace(326, 346, 40) #vertical axis
param2_values = np.linspace(326, 346, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 302.5, Bj = 0.4 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.4000000000000001
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 225.8s - Est. remaining: 677.3s
# Progress: 50% complete (800/1600) - Elapsed: 814.7s - Est. remaining: 814.7s
# Progress: 75% complete (1200/1600) - Elapsed: 1821.4s - Est. remaining: 607.1s
# Progress: 100% complete (1600/1600) - Elapsed: 3102.5s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 18
#   Flowering time: 335.23 days
#   Column sum: 7.6993
#
# Raster process complete in 3102.8s!
#
# Total execution time: 3102.79 seconds

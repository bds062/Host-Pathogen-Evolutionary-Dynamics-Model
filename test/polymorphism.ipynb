# %%
import sys
sys.path.append('../src')

from model import Model
from plot import RasterModel, GraphModel
import numpy as np
import time

# %%
param1_values = np.linspace(205, 225, 40) #vertical axis
param2_values = np.linspace(205, 225, 40) #horizontal axis



model = Model(maturity=2/365, t = (0, 365 * 400), germination_time = 182.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 2.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 120.3s - Est. remaining: 361.0s
# Progress: 50% complete (800/1600) - Elapsed: 447.2s - Est. remaining: 447.2s
# Progress: 75% complete (1200/1600) - Elapsed: 951.5s - Est. remaining: 317.2s
# Progress: 100% complete (1600/1600) - Elapsed: 1644.4s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 28
#   Flowering time: 219.36 days
#   Column sum: 8.2488
#
# Raster process complete in 1644.6s!
#
# Total execution time: 1644.70 seconds

# %%
param1_values = np.linspace(205, 225, 40) #vertical axis
param2_values = np.linspace(205, 225, 40) #horizontal axis



model = Model(maturity=4/365, t = (0, 365 * 400), germination_time = 182.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 4.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 121.3s - Est. remaining: 363.8s
# Progress: 50% complete (800/1600) - Elapsed: 428.4s - Est. remaining: 428.4s
# Progress: 75% complete (1200/1600) - Elapsed: 930.5s - Est. remaining: 310.2s
# Progress: 100% complete (1600/1600) - Elapsed: 1616.3s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 23
#   Flowering time: 216.79 days
#   Column sum: 8.1514
#
# Raster process complete in 1616.6s!
#
# Total execution time: 1616.57 seconds

# %%
param1_values = np.linspace(205, 225, 40) #vertical axis
param2_values = np.linspace(205, 225, 40) #horizontal axis



model = Model(maturity=8/365, t = (0, 365 * 400), germination_time = 182.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 8.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 120.6s - Est. remaining: 361.7s
# Progress: 50% complete (800/1600) - Elapsed: 428.1s - Est. remaining: 428.1s
# Progress: 75% complete (1200/1600) - Elapsed: 928.8s - Est. remaining: 309.6s
# Progress: 100% complete (1600/1600) - Elapsed: 1617.3s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 18
#   Flowering time: 214.23 days
#   Column sum: 8.9993
#
# Raster process complete in 1617.5s!
#
# Total execution time: 1617.51 seconds

# %%
param1_values = np.linspace(205, 225, 40) #vertical axis
param2_values = np.linspace(205, 225, 40) #horizontal axis



model = Model(maturity=16/365, t = (0, 365 * 400), germination_time = 182.5, Bj = 0.2 / 365, infected_time=182.5, infected_time2=182.5)
# graph_model = GraphModel(model)
raster_model = RasterModel(model, 'infected_time', 'infected_time2', param1_values, param2_values)

print("Maturation rate:", model.maturity*365)
print("BetaJ: ", model.Bj*365)
print("BetaA: ", model.Bv*365)


start_time = time.time()
# graph_model.graph()
# print("Evaluation (genotype1/genotype1+2): ", model.evaluate(model.solution))
# raster_model.sweep_1d(param_num=1)
# raster_model.plot_1d()
raster_model.raster()  # Uses all 8 cores automatically
end_time = time.time()
print(f"\nTotal execution time: {end_time - start_time:.2f} seconds")

raster_model.plot_heatmap()
# Out:
# Maturation rate: 16.0
# BetaJ:  0.20000000000000004
# BetaA:  0.025000000000000005
# Starting parallel raster process with 20 processes...
# Total iterations: 1600
# Progress: 0% complete
# Progress: 25% complete (400/1600) - Elapsed: 120.7s - Est. remaining: 362.2s
# Progress: 50% complete (800/1600) - Elapsed: 434.0s - Est. remaining: 434.0s
# Progress: 75% complete (1200/1600) - Elapsed: 924.8s - Est. remaining: 308.3s
# Progress: 100% complete (1600/1600) - Elapsed: 1615.9s - Est. remaining: 0.0s
#
# Filling symmetric values or running missing simulations...
#
# ESS (Evolutionarily Stable Strategy) found:
#   Column index: 16
#   Flowering time: 213.21 days
#   Column sum: 9.1679
#
# Raster process complete in 1616.0s!
#
# Total execution time: 1616.00 seconds
